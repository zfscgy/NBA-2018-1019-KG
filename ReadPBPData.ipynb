# %%
import pandas as pd

# %%
pbp = pd.read_csv("./Data/NBA-PBP-2018-2019.csv", dtype=str)
pbp.fillna('', inplace=True)

# %%
pbp = pbp.groupby(["Date", "HomeTeam", "AwayTeam"])

# %%
pbp_dict = dict(list(pbp))

# %%
for key in pbp_dict.keys():
    print(key)
# Out:
# ('April 1 2019', 'BOS', 'MIA')
# ('April 1 2019', 'BRK', 'MIL')
# ('April 1 2019', 'DAL', 'PHI')
# ('April 1 2019', 'IND', 'DET')
# ('April 1 2019', 'MIN', 'POR')
# ('April 1 2019', 'NYK', 'CHI')
# ('April 1 2019', 'PHO', 'CLE')
# ('April 1 2019', 'TOR', 'ORL')
# ('April 1 2019', 'UTA', 'CHO')
# ('April 10 2019', 'ATL', 'IND')
# ('April 10 2019', 'BRK', 'MIA')
# ('April 10 2019', 'CHO', 'ORL')
# ('April 10 2019', 'DEN', 'MIN')
# ('April 10 2019', 'LAC', 'UTA')
# ('April 10 2019', 'MEM', 'GSW')
# ('April 10 2019', 'MIL', 'OKC')
# ('April 10 2019', 'NYK', 'DET')
# ('April 10 2019', 'PHI', 'CHI')
# ('April 10 2019', 'POR', 'SAC')
# ('April 10 2019', 'SAS', 'DAL')
# ('April 13 2019', 'DEN', 'SAS')
# ('April 13 2019', 'GSW', 'LAC')
# ('April 13 2019', 'PHI', 'BRK')
# ('April 13 2019', 'TOR', 'ORL')
# ('April 14 2019', 'BOS', 'IND')
# ('April 14 2019', 'HOU', 'UTA')
# ('April 14 2019', 'MIL', 'DET')
# ('April 14 2019', 'POR', 'OKC')
# ('April 15 2019', 'GSW', 'LAC')
# ('April 15 2019', 'PHI', 'BRK')
# ('April 16 2019', 'DEN', 'SAS')
# ('April 16 2019', 'POR', 'OKC')
# ('April 16 2019', 'TOR', 'ORL')
# ('April 17 2019', 'BOS', 'IND')
# ('April 17 2019', 'HOU', 'UTA')
# ('April 17 2019', 'MIL', 'DET')
# ('April 18 2019', 'BRK', 'PHI')
# ('April 18 2019', 'LAC', 'GSW')
# ('April 18 2019', 'SAS', 'DEN')
# ('April 19 2019', 'IND', 'BOS')
# ('April 19 2019', 'OKC', 'POR')
# ('April 19 2019', 'ORL', 'TOR')
# ('April 2 2019', 'GSW', 'DEN')
# ('April 2 2019', 'OKC', 'LAL')
# ('April 2 2019', 'SAC', 'HOU')
# ('April 2 2019', 'SAS', 'ATL')
# ('April 20 2019', 'BRK', 'PHI')
# ('April 20 2019', 'DET', 'MIL')
# ('April 20 2019', 'SAS', 'DEN')
# ('April 20 2019', 'UTA', 'HOU')
# ('April 21 2019', 'IND', 'BOS')
# ('April 21 2019', 'LAC', 'GSW')
# ('April 21 2019', 'OKC', 'POR')
# ('April 21 2019', 'ORL', 'TOR')
# ('April 22 2019', 'DET', 'MIL')
# ('April 22 2019', 'UTA', 'HOU')
# ('April 23 2019', 'DEN', 'SAS')
# ('April 23 2019', 'PHI', 'BRK')
# ('April 23 2019', 'POR', 'OKC')
# ('April 23 2019', 'TOR', 'ORL')
# ('April 24 2019', 'GSW', 'LAC')
# ('April 24 2019', 'HOU', 'UTA')
# ('April 25 2019', 'SAS', 'DEN')
# ('April 26 2019', 'LAC', 'GSW')
# ('April 27 2019', 'DEN', 'SAS')
# ('April 27 2019', 'TOR', 'PHI')
# ('April 28 2019', 'GSW', 'HOU')
# ('April 28 2019', 'MIL', 'BOS')
# ('April 29 2019', 'DEN', 'POR')
# ('April 29 2019', 'TOR', 'PHI')
# ('April 3 2019', 'ATL', 'PHI')
# ('April 3 2019', 'BRK', 'TOR')
# ('April 3 2019', 'DAL', 'MIN')
# ('April 3 2019', 'DEN', 'SAS')
# ('April 3 2019', 'DET', 'IND')
# ('April 3 2019', 'LAC', 'HOU')
# ('April 3 2019', 'MIA', 'BOS')
# ('April 3 2019', 'NOP', 'CHO')
# ('April 3 2019', 'ORL', 'NYK')
# ('April 3 2019', 'PHO', 'UTA')
# ('April 3 2019', 'POR', 'MEM')
# ('April 3 2019', 'WAS', 'CHI')
# ('April 30 2019', 'GSW', 'HOU')
# ('April 30 2019', 'MIL', 'BOS')
# ('April 4 2019', 'LAL', 'GSW')
# ('April 4 2019', 'PHI', 'MIL')
# ('April 4 2019', 'SAC', 'CLE')
# ('April 5 2019', 'CHO', 'TOR')
# ('April 5 2019', 'DAL', 'MEM')
# ('April 5 2019', 'DEN', 'POR')
# ('April 5 2019', 'GSW', 'CLE')
# ('April 5 2019', 'HOU', 'NYK')
# ('April 5 2019', 'IND', 'BOS')
# ('April 5 2019', 'LAC', 'LAL')
# ('April 5 2019', 'MIN', 'MIA')
# ('April 5 2019', 'OKC', 'DET')
# ('April 5 2019', 'ORL', 'ATL')
# ('April 5 2019', 'PHO', 'NOP')
# ('April 5 2019', 'UTA', 'SAC')
# ('April 5 2019', 'WAS', 'SAS')
# ('April 6 2019', 'CHI', 'PHI')
# ('April 6 2019', 'MIL', 'BRK')
# ('April 7 2019', 'BOS', 'ORL')
# ('April 7 2019', 'CLE', 'SAS')
# ('April 7 2019', 'DET', 'CHO')
# ('April 7 2019', 'GSW', 'LAC')
# ('April 7 2019', 'HOU', 'PHO')
# ('April 7 2019', 'IND', 'BRK')
# ('April 7 2019', 'LAL', 'UTA')
# ('April 7 2019', 'MEM', 'DAL')
# ('April 7 2019', 'MIL', 'ATL')
# ('April 7 2019', 'MIN', 'OKC')
# ('April 7 2019', 'NYK', 'WAS')
# ('April 7 2019', 'POR', 'DEN')
# ('April 7 2019', 'SAC', 'NOP')
# ('April 7 2019', 'TOR', 'MIA')
# ('April 9 2019', 'CHI', 'NYK')
# ('April 9 2019', 'CLE', 'CHO')
# ('April 9 2019', 'DAL', 'PHO')
# ('April 9 2019', 'DET', 'MEM')
# ('April 9 2019', 'LAL', 'POR')
# ('April 9 2019', 'MIA', 'PHI')
# ('April 9 2019', 'MIN', 'TOR')
# ('April 9 2019', 'NOP', 'GSW')
# ('April 9 2019', 'OKC', 'HOU')
# ('April 9 2019', 'UTA', 'DEN')
# ('April 9 2019', 'WAS', 'BOS')
# ('December 1 2018', 'CLE', 'TOR')
# ('December 1 2018', 'DET', 'GSW')
# ('December 1 2018', 'HOU', 'CHI')
# ('December 1 2018', 'MIN', 'BOS')
# ('December 1 2018', 'NYK', 'MIL')
# ('December 1 2018', 'SAC', 'IND')
# ('December 1 2018', 'WAS', 'BRK')
# ('December 10 2018', 'BOS', 'NOP')
# ('December 10 2018', 'CHI', 'SAC')
# ('December 10 2018', 'DAL', 'ORL')
# ('December 10 2018', 'DEN', 'MEM')
# ('December 10 2018', 'GSW', 'MIN')
# ('December 10 2018', 'IND', 'WAS')
# ('December 10 2018', 'LAL', 'MIA')
# ('December 10 2018', 'MIL', 'CLE')
# ('December 10 2018', 'OKC', 'UTA')
# ('December 10 2018', 'PHI', 'DET')
# ('December 10 2018', 'PHO', 'LAC')
# ('December 11 2018', 'HOU', 'POR')
# ('December 11 2018', 'LAC', 'TOR')
# ('December 11 2018', 'SAS', 'PHO')
# ('December 12 2018', 'CHO', 'DET')
# ('December 12 2018', 'CLE', 'NYK')
# ('December 12 2018', 'DAL', 'ATL')
# ('December 12 2018', 'GSW', 'TOR')
# ('December 12 2018', 'IND', 'MIL')
# ('December 12 2018', 'MEM', 'POR')
# ('December 12 2018', 'NOP', 'OKC')
# ('December 12 2018', 'PHI', 'BRK')
# ('December 12 2018', 'SAC', 'MIN')
# ('December 12 2018', 'UTA', 'MIA')
# ('December 12 2018', 'WAS', 'BOS')
# ('December 13 2018', 'HOU', 'LAL')
# ('December 13 2018', 'ORL', 'CHI')
# ('December 13 2018', 'PHO', 'DAL')
# ('December 13 2018', 'SAS', 'LAC')
# ('December 14 2018', 'BOS', 'ATL')
# ('December 14 2018', 'BRK', 'WAS')
# ('December 14 2018', 'CHO', 'NYK')
# ('December 14 2018', 'CLE', 'MIL')
# ('December 14 2018', 'DEN', 'OKC')
# ('December 14 2018', 'MEM', 'MIA')
# ('December 14 2018', 'PHI', 'IND')
# ('December 14 2018', 'POR', 'TOR')
# ('December 14 2018', 'SAC', 'GSW')
# ('December 15 2018', 'CHO', 'LAL')
# ('December 15 2018', 'DET', 'BOS')
# ('December 15 2018', 'MEM', 'HOU')
# ('December 15 2018', 'OKC', 'LAC')
# ('December 15 2018', 'ORL', 'UTA')
# ('December 15 2018', 'PHO', 'MIN')
# ('December 15 2018', 'SAS', 'CHI')
# ('December 16 2018', 'BRK', 'ATL')
# ('December 16 2018', 'CLE', 'PHI')
# ('December 16 2018', 'DAL', 'SAC')
# ('December 16 2018', 'DEN', 'TOR')
# ('December 16 2018', 'IND', 'NYK')
# ('December 16 2018', 'NOP', 'MIA')
# ('December 16 2018', 'WAS', 'LAL')
# ('December 17 2018', 'DET', 'MIL')
# ('December 17 2018', 'GSW', 'MEM')
# ('December 17 2018', 'HOU', 'UTA')
# ('December 17 2018', 'LAC', 'POR')
# ('December 17 2018', 'MIN', 'SAC')
# ('December 17 2018', 'NYK', 'PHO')
# ('December 17 2018', 'OKC', 'CHI')
# ('December 17 2018', 'SAS', 'PHI')
# ('December 18 2018', 'ATL', 'WAS')
# ('December 18 2018', 'BRK', 'LAL')
# ('December 18 2018', 'DEN', 'DAL')
# ('December 18 2018', 'IND', 'CLE')
# ('December 19 2018', 'BOS', 'PHO')
# ('December 19 2018', 'CHI', 'BRK')
# ('December 19 2018', 'CHO', 'CLE')
# ('December 19 2018', 'HOU', 'WAS')
# ('December 19 2018', 'MIL', 'NOP')
# ('December 19 2018', 'MIN', 'DET')
# ('December 19 2018', 'ORL', 'SAS')
# ('December 19 2018', 'PHI', 'NYK')
# ('December 19 2018', 'POR', 'MEM')
# ('December 19 2018', 'SAC', 'OKC')
# ('December 19 2018', 'TOR', 'IND')
# ('December 19 2018', 'UTA', 'GSW')
# ('December 2 2018', 'CHO', 'NOP')
# ('December 2 2018', 'DAL', 'LAC')
# ('December 2 2018', 'LAL', 'PHO')
# ('December 2 2018', 'MIA', 'UTA')
# ('December 2 2018', 'PHI', 'MEM')
# ('December 2 2018', 'SAS', 'POR')
# ('December 20 2018', 'LAC', 'DAL')
# ('December 20 2018', 'MIA', 'HOU')
# ('December 21 2018', 'BOS', 'MIL')
# ('December 21 2018', 'BRK', 'IND')
# ('December 21 2018', 'CHI', 'ORL')
# ('December 21 2018', 'CHO', 'DET')
# ('December 21 2018', 'LAL', 'NOP')
# ('December 21 2018', 'NYK', 'ATL')
# ('December 21 2018', 'POR', 'UTA')
# ('December 21 2018', 'SAC', 'MEM')
# ('December 21 2018', 'SAS', 'MIN')
# ('December 21 2018', 'TOR', 'CLE')
# ('December 22 2018', 'GSW', 'DAL')
# ('December 22 2018', 'HOU', 'SAS')
# ('December 22 2018', 'LAC', 'DEN')
# ('December 22 2018', 'MIA', 'MIL')
# ('December 22 2018', 'PHI', 'TOR')
# ('December 22 2018', 'UTA', 'OKC')
# ('December 22 2018', 'WAS', 'PHO')
# ('December 23 2018', 'BOS', 'CHO')
# ('December 23 2018', 'BRK', 'PHO')
# ('December 23 2018', 'CLE', 'CHI')
# ('December 23 2018', 'DET', 'ATL')
# ('December 23 2018', 'GSW', 'LAC')
# ('December 23 2018', 'IND', 'WAS')
# ('December 23 2018', 'LAL', 'MEM')
# ('December 23 2018', 'OKC', 'MIN')
# ('December 23 2018', 'ORL', 'MIA')
# ('December 23 2018', 'POR', 'DAL')
# ('December 23 2018', 'SAC', 'NOP')
# ('December 25 2018', 'BOS', 'PHI')
# ('December 25 2018', 'GSW', 'LAL')
# ('December 25 2018', 'HOU', 'OKC')
# ('December 25 2018', 'NYK', 'MIL')
# ('December 25 2018', 'UTA', 'POR')
# ('December 26 2018', 'ATL', 'IND')
# ('December 26 2018', 'BRK', 'CHO')
# ('December 26 2018', 'CHI', 'MIN')
# ('December 26 2018', 'DAL', 'NOP')
# ('December 26 2018', 'DET', 'WAS')
# ('December 26 2018', 'LAC', 'SAC')
# ('December 26 2018', 'MEM', 'CLE')
# ('December 26 2018', 'MIA', 'TOR')
# ('December 26 2018', 'ORL', 'PHO')
# ('December 26 2018', 'SAS', 'DEN')
# ('December 27 2018', 'GSW', 'POR')
# ('December 27 2018', 'HOU', 'BOS')
# ('December 27 2018', 'MIL', 'NYK')
# ('December 27 2018', 'SAC', 'LAL')
# ('December 27 2018', 'UTA', 'PHI')
# ('December 28 2018', 'CHO', 'BRK')
# ('December 28 2018', 'DEN', 'SAS')
# ('December 28 2018', 'IND', 'DET')
# ('December 28 2018', 'LAL', 'LAC')
# ('December 28 2018', 'MIA', 'CLE')
# ('December 28 2018', 'MIN', 'ATL')
# ('December 28 2018', 'NOP', 'DAL')
# ('December 28 2018', 'ORL', 'TOR')
# ('December 28 2018', 'PHO', 'OKC')
# ('December 28 2018', 'WAS', 'CHI')
# ('December 29 2018', 'ATL', 'CLE')
# ('December 29 2018', 'LAC', 'SAS')
# ('December 29 2018', 'MEM', 'BOS')
# ('December 29 2018', 'MIL', 'BRK')
# ('December 29 2018', 'NOP', 'HOU')
# ('December 29 2018', 'PHO', 'DEN')
# ('December 29 2018', 'POR', 'GSW')
# ('December 29 2018', 'UTA', 'NYK')
# ('December 29 2018', 'WAS', 'CHO')
# ('December 3 2018', 'ATL', 'GSW')
# ('December 3 2018', 'BRK', 'CLE')
# ('December 3 2018', 'DET', 'OKC')
# ('December 3 2018', 'MIN', 'HOU')
# ('December 3 2018', 'NOP', 'LAC')
# ('December 3 2018', 'NYK', 'WAS')
# ('December 3 2018', 'TOR', 'DEN')
# ('December 30 2018', 'DAL', 'OKC')
# ('December 30 2018', 'LAL', 'SAC')
# ('December 30 2018', 'MIA', 'MIN')
# ('December 30 2018', 'ORL', 'DET')
# ('December 30 2018', 'POR', 'PHI')
# ('December 30 2018', 'TOR', 'CHI')
# ('December 31 2018', 'CHO', 'ORL')
# ('December 31 2018', 'HOU', 'MEM')
# ('December 31 2018', 'IND', 'ATL')
# ('December 31 2018', 'NOP', 'MIN')
# ('December 31 2018', 'OKC', 'DAL')
# ('December 31 2018', 'PHO', 'GSW')
# ('December 31 2018', 'SAS', 'BOS')
# ('December 4 2018', 'DAL', 'POR')
# ('December 4 2018', 'IND', 'CHI')
# ('December 4 2018', 'MIA', 'ORL')
# ('December 4 2018', 'PHO', 'SAC')
# ('December 4 2018', 'UTA', 'SAS')
# ('December 5 2018', 'ATL', 'WAS')
# ('December 5 2018', 'BRK', 'OKC')
# ('December 5 2018', 'CLE', 'GSW')
# ('December 5 2018', 'LAL', 'SAS')
# ('December 5 2018', 'MEM', 'LAC')
# ('December 5 2018', 'MIL', 'DET')
# ('December 5 2018', 'MIN', 'CHO')
# ('December 5 2018', 'NOP', 'DAL')
# ('December 5 2018', 'ORL', 'DEN')
# ('December 5 2018', 'TOR', 'PHI')
# ('December 6 2018', 'BOS', 'NYK')
# ('December 6 2018', 'POR', 'PHO')
# ('December 6 2018', 'UTA', 'HOU')
# ('December 7 2018', 'BRK', 'TOR')
# ('December 7 2018', 'CHI', 'OKC')
# ('December 7 2018', 'CHO', 'DEN')
# ('December 7 2018', 'CLE', 'SAC')
# ('December 7 2018', 'DET', 'PHI')
# ('December 7 2018', 'MIL', 'GSW')
# ('December 7 2018', 'NOP', 'MEM')
# ('December 7 2018', 'ORL', 'IND')
# ('December 7 2018', 'PHO', 'MIA')
# ('December 7 2018', 'SAS', 'LAL')
# ('December 8 2018', 'ATL', 'DEN')
# ('December 8 2018', 'CHI', 'BOS')
# ('December 8 2018', 'CLE', 'WAS')
# ('December 8 2018', 'DAL', 'HOU')
# ('December 8 2018', 'IND', 'SAC')
# ('December 8 2018', 'LAC', 'MIA')
# ('December 8 2018', 'MEM', 'LAL')
# ('December 8 2018', 'NYK', 'BRK')
# ('December 8 2018', 'POR', 'MIN')
# ('December 9 2018', 'DET', 'NOP')
# ('December 9 2018', 'NYK', 'CHO')
# ('December 9 2018', 'SAS', 'UTA')
# ('December 9 2018', 'TOR', 'MIL')
# ('February 1 2019', 'CHO', 'MEM')
# ('February 1 2019', 'DEN', 'HOU')
# ('February 1 2019', 'MIA', 'OKC')
# ('February 1 2019', 'NYK', 'BOS')
# ('February 1 2019', 'UTA', 'ATL')
# ('February 10 2019', 'ATL', 'ORL')
# ('February 10 2019', 'DAL', 'POR')
# ('February 10 2019', 'GSW', 'MIA')
# ('February 10 2019', 'PHI', 'LAL')
# ('February 10 2019', 'SAC', 'PHO')
# ('February 11 2019', 'CHI', 'MIL')
# ('February 11 2019', 'CLE', 'NYK')
# ('February 11 2019', 'DEN', 'MIA')
# ('February 11 2019', 'DET', 'WAS')
# ('February 11 2019', 'HOU', 'DAL')
# ('February 11 2019', 'IND', 'CHO')
# ('February 11 2019', 'MIN', 'LAC')
# ('February 11 2019', 'OKC', 'POR')
# ('February 11 2019', 'TOR', 'BRK')
# ('February 12 2019', 'ATL', 'LAL')
# ('February 12 2019', 'GSW', 'UTA')
# ('February 12 2019', 'MEM', 'SAS')
# ('February 12 2019', 'NOP', 'ORL')
# ('February 12 2019', 'PHI', 'BOS')
# ('February 13 2019', 'BOS', 'DET')
# ('February 13 2019', 'CHI', 'MEM')
# ('February 13 2019', 'CLE', 'BRK')
# ('February 13 2019', 'DAL', 'MIA')
# ('February 13 2019', 'DEN', 'SAC')
# ('February 13 2019', 'IND', 'MIL')
# ('February 13 2019', 'LAC', 'PHO')
# ('February 13 2019', 'MIN', 'HOU')
# ('February 13 2019', 'NYK', 'PHI')
# ('February 13 2019', 'POR', 'GSW')
# ('February 13 2019', 'TOR', 'WAS')
# ('February 14 2019', 'ATL', 'NYK')
# ('February 14 2019', 'NOP', 'OKC')
# ('February 14 2019', 'ORL', 'CHO')
# ('February 2 2019', 'CHO', 'CHI')
# ('February 2 2019', 'CLE', 'DAL')
# ('February 2 2019', 'DET', 'LAC')
# ('February 2 2019', 'GSW', 'LAL')
# ('February 2 2019', 'MIA', 'IND')
# ('February 2 2019', 'MIN', 'DEN')
# ('February 2 2019', 'ORL', 'BRK')
# ('February 2 2019', 'PHO', 'ATL')
# ('February 2 2019', 'SAC', 'PHI')
# ('February 2 2019', 'SAS', 'NOP')
# ('February 2 2019', 'UTA', 'HOU')
# ('February 2 2019', 'WAS', 'MIL')
# ('February 21 2019', 'BRK', 'POR')
# ('February 21 2019', 'CLE', 'PHO')
# ('February 21 2019', 'GSW', 'SAC')
# ('February 21 2019', 'LAL', 'HOU')
# ('February 21 2019', 'MIL', 'BOS')
# ('February 21 2019', 'PHI', 'MIA')
# ('February 22 2019', 'ATL', 'DET')
# ('February 22 2019', 'CHO', 'WAS')
# ('February 22 2019', 'DAL', 'DEN')
# ('February 22 2019', 'IND', 'NOP')
# ('February 22 2019', 'MEM', 'LAC')
# ('February 22 2019', 'NYK', 'MIN')
# ('February 22 2019', 'OKC', 'UTA')
# ('February 22 2019', 'ORL', 'CHI')
# ('February 22 2019', 'TOR', 'SAS')
# ('February 23 2019', 'ATL', 'PHO')
# ('February 23 2019', 'CHI', 'BOS')
# ('February 23 2019', 'CHO', 'BRK')
# ('February 23 2019', 'CLE', 'MEM')
# ('February 23 2019', 'GSW', 'HOU')
# ('February 23 2019', 'MIA', 'DET')
# ('February 23 2019', 'MIL', 'MIN')
# ('February 23 2019', 'NOP', 'LAL')
# ('February 23 2019', 'OKC', 'SAC')
# ('February 23 2019', 'PHI', 'POR')
# ('February 23 2019', 'UTA', 'DAL')
# ('February 23 2019', 'WAS', 'IND')
# ('February 24 2019', 'DEN', 'LAC')
# ('February 24 2019', 'NYK', 'SAS')
# ('February 24 2019', 'TOR', 'ORL')
# ('February 25 2019', 'BRK', 'SAS')
# ('February 25 2019', 'CHI', 'MIL')
# ('February 25 2019', 'CHO', 'GSW')
# ('February 25 2019', 'CLE', 'POR')
# ('February 25 2019', 'DET', 'IND')
# ('February 25 2019', 'HOU', 'ATL')
# ('February 25 2019', 'LAC', 'DAL')
# ('February 25 2019', 'MEM', 'LAL')
# ('February 25 2019', 'MIA', 'PHO')
# ('February 25 2019', 'MIN', 'SAC')
# ('February 25 2019', 'NOP', 'PHI')
# ('February 26 2019', 'DEN', 'OKC')
# ('February 26 2019', 'NYK', 'ORL')
# ('February 26 2019', 'TOR', 'BOS')
# ('February 27 2019', 'ATL', 'MIN')
# ('February 27 2019', 'BOS', 'POR')
# ('February 27 2019', 'BRK', 'WAS')
# ('February 27 2019', 'CHO', 'HOU')
# ('February 27 2019', 'DAL', 'IND')
# ('February 27 2019', 'LAL', 'NOP')
# ('February 27 2019', 'MEM', 'CHI')
# ('February 27 2019', 'MIA', 'GSW')
# ('February 27 2019', 'SAC', 'MIL')
# ('February 27 2019', 'SAS', 'DET')
# ('February 27 2019', 'UTA', 'LAC')
# ('February 28 2019', 'DEN', 'UTA')
# ('February 28 2019', 'HOU', 'MIA')
# ('February 28 2019', 'IND', 'MIN')
# ('February 28 2019', 'NYK', 'CLE')
# ('February 28 2019', 'OKC', 'PHI')
# ('February 28 2019', 'ORL', 'GSW')
# ('February 3 2019', 'BOS', 'OKC')
# ('February 3 2019', 'NYK', 'MEM')
# ('February 3 2019', 'TOR', 'LAC')
# ('February 4 2019', 'BRK', 'MIL')
# ('February 4 2019', 'DET', 'DEN')
# ('February 4 2019', 'NOP', 'IND')
# ('February 4 2019', 'PHO', 'HOU')
# ('February 4 2019', 'SAC', 'SAS')
# ('February 4 2019', 'WAS', 'ATL')
# ('February 5 2019', 'CHO', 'LAC')
# ('February 5 2019', 'CLE', 'BOS')
# ('February 5 2019', 'IND', 'LAL')
# ('February 5 2019', 'MEM', 'MIN')
# ('February 5 2019', 'NYK', 'DET')
# ('February 5 2019', 'OKC', 'ORL')
# ('February 5 2019', 'PHI', 'TOR')
# ('February 5 2019', 'POR', 'MIA')
# ('February 6 2019', 'BRK', 'DEN')
# ('February 6 2019', 'CHI', 'NOP')
# ('February 6 2019', 'DAL', 'CHO')
# ('February 6 2019', 'GSW', 'SAS')
# ('February 6 2019', 'MIL', 'WAS')
# ('February 6 2019', 'SAC', 'HOU')
# ('February 6 2019', 'UTA', 'PHO')
# ('February 7 2019', 'ATL', 'TOR')
# ('February 7 2019', 'BOS', 'LAL')
# ('February 7 2019', 'IND', 'LAC')
# ('February 7 2019', 'OKC', 'MEM')
# ('February 7 2019', 'ORL', 'MIN')
# ('February 7 2019', 'POR', 'SAS')
# ('February 8 2019', 'BRK', 'CHI')
# ('February 8 2019', 'DAL', 'MIL')
# ('February 8 2019', 'DET', 'NYK')
# ('February 8 2019', 'NOP', 'MIN')
# ('February 8 2019', 'PHI', 'DEN')
# ('February 8 2019', 'PHO', 'GSW')
# ('February 8 2019', 'SAC', 'MIA')
# ('February 8 2019', 'WAS', 'CLE')
# ('February 9 2019', 'ATL', 'CHO')
# ('February 9 2019', 'BOS', 'LAC')
# ('February 9 2019', 'CHI', 'WAS')
# ('February 9 2019', 'HOU', 'OKC')
# ('February 9 2019', 'IND', 'CLE')
# ('February 9 2019', 'MEM', 'NOP')
# ('February 9 2019', 'MIL', 'ORL')
# ('February 9 2019', 'NYK', 'TOR')
# ('February 9 2019', 'UTA', 'SAS')
# ('January 1 2019', 'DEN', 'NYK')
# ('January 1 2019', 'LAC', 'PHI')
# ('January 1 2019', 'MIL', 'DET')
# ('January 1 2019', 'SAC', 'POR')
# ('January 1 2019', 'TOR', 'UTA')
# ('January 10 2019', 'DEN', 'LAC')
# ('January 10 2019', 'MIA', 'BOS')
# ('January 10 2019', 'SAC', 'DET')
# ('January 10 2019', 'SAS', 'OKC')
# ('January 11 2019', 'GSW', 'CHI')
# ('January 11 2019', 'HOU', 'CLE')
# ('January 11 2019', 'MIN', 'DAL')
# ('January 11 2019', 'NYK', 'IND')
# ('January 11 2019', 'PHI', 'ATL')
# ('January 11 2019', 'POR', 'CHO')
# ('January 11 2019', 'TOR', 'BRK')
# ('January 11 2019', 'UTA', 'LAL')
# ('January 11 2019', 'WAS', 'MIL')
# ('January 12 2019', 'LAC', 'DET')
# ('January 12 2019', 'MIA', 'MEM')
# ('January 12 2019', 'MIN', 'NOP')
# ('January 12 2019', 'OKC', 'SAS')
# ('January 12 2019', 'ORL', 'BOS')
# ('January 12 2019', 'PHO', 'DEN')
# ('January 12 2019', 'SAC', 'CHO')
# ('January 12 2019', 'UTA', 'CHI')
# ('January 13 2019', 'ATL', 'MIL')
# ('January 13 2019', 'DAL', 'GSW')
# ('January 13 2019', 'DEN', 'POR')
# ('January 13 2019', 'LAL', 'CLE')
# ('January 13 2019', 'NYK', 'PHI')
# ('January 13 2019', 'ORL', 'HOU')
# ('January 13 2019', 'WAS', 'TOR')
# ('January 14 2019', 'BRK', 'BOS')
# ('January 14 2019', 'HOU', 'MEM')
# ('January 14 2019', 'LAC', 'NOP')
# ('January 14 2019', 'SAC', 'POR')
# ('January 14 2019', 'SAS', 'CHO')
# ('January 14 2019', 'UTA', 'DET')
# ('January 15 2019', 'ATL', 'OKC')
# ('January 15 2019', 'DEN', 'GSW')
# ('January 15 2019', 'IND', 'PHO')
# ('January 15 2019', 'LAL', 'CHI')
# ('January 15 2019', 'MIL', 'MIA')
# ('January 15 2019', 'PHI', 'MIN')
# ('January 16 2019', 'BOS', 'TOR')
# ('January 16 2019', 'DAL', 'SAS')
# ('January 16 2019', 'DET', 'ORL')
# ('January 16 2019', 'GSW', 'NOP')
# ('January 16 2019', 'HOU', 'BRK')
# ('January 16 2019', 'LAC', 'UTA')
# ('January 16 2019', 'MEM', 'MIL')
# ('January 16 2019', 'POR', 'CLE')
# ('January 17 2019', 'CHO', 'SAC')
# ('January 17 2019', 'DEN', 'CHI')
# ('January 17 2019', 'IND', 'PHI')
# ('January 17 2019', 'OKC', 'LAL')
# ('January 17 2019', 'TOR', 'PHO')
# ('January 17 2019', 'WAS', 'NYK')
# ('January 18 2019', 'BOS', 'MEM')
# ('January 18 2019', 'DET', 'MIA')
# ('January 18 2019', 'LAC', 'GSW')
# ('January 18 2019', 'MIN', 'SAS')
# ('January 18 2019', 'ORL', 'BRK')
# ('January 18 2019', 'POR', 'NOP')
# ('January 18 2019', 'UTA', 'CLE')
# ('January 19 2019', 'ATL', 'BOS')
# ('January 19 2019', 'CHI', 'MIA')
# ('January 19 2019', 'CHO', 'PHO')
# ('January 19 2019', 'DEN', 'CLE')
# ('January 19 2019', 'DET', 'SAC')
# ('January 19 2019', 'HOU', 'LAL')
# ('January 19 2019', 'IND', 'DAL')
# ('January 19 2019', 'ORL', 'MIL')
# ('January 19 2019', 'PHI', 'OKC')
# ('January 19 2019', 'TOR', 'MEM')
# ('January 2 2019', 'BOS', 'MIN')
# ('January 2 2019', 'BRK', 'NOP')
# ('January 2 2019', 'CHI', 'ORL')
# ('January 2 2019', 'CHO', 'DAL')
# ('January 2 2019', 'CLE', 'MIA')
# ('January 2 2019', 'LAL', 'OKC')
# ('January 2 2019', 'MEM', 'DET')
# ('January 2 2019', 'PHO', 'PHI')
# ('January 2 2019', 'WAS', 'ATL')
# ('January 20 2019', 'IND', 'CHO')
# ('January 20 2019', 'MIN', 'PHO')
# ('January 20 2019', 'SAS', 'LAC')
# ('January 21 2019', 'ATL', 'ORL')
# ('January 21 2019', 'BOS', 'MIA')
# ('January 21 2019', 'BRK', 'SAC')
# ('January 21 2019', 'CLE', 'CHI')
# ('January 21 2019', 'LAL', 'GSW')
# ('January 21 2019', 'MEM', 'NOP')
# ('January 21 2019', 'MIL', 'DAL')
# ('January 21 2019', 'NYK', 'OKC')
# ('January 21 2019', 'PHI', 'HOU')
# ('January 21 2019', 'UTA', 'POR')
# ('January 21 2019', 'WAS', 'DET')
# ('January 22 2019', 'DAL', 'LAC')
# ('January 22 2019', 'OKC', 'POR')
# ('January 22 2019', 'PHO', 'MIN')
# ('January 22 2019', 'TOR', 'SAC')
# ('January 23 2019', 'BOS', 'CLE')
# ('January 23 2019', 'BRK', 'ORL')
# ('January 23 2019', 'CHI', 'ATL')
# ('January 23 2019', 'IND', 'TOR')
# ('January 23 2019', 'MEM', 'CHO')
# ('January 23 2019', 'MIA', 'LAC')
# ('January 23 2019', 'NOP', 'DET')
# ('January 23 2019', 'NYK', 'HOU')
# ('January 23 2019', 'PHI', 'SAS')
# ('January 23 2019', 'UTA', 'DEN')
# ('January 24 2019', 'LAL', 'MIN')
# ('January 24 2019', 'OKC', 'NOP')
# ('January 24 2019', 'PHO', 'POR')
# ('January 24 2019', 'WAS', 'GSW')
# ('January 25 2019', 'BRK', 'NYK')
# ('January 25 2019', 'CHI', 'LAC')
# ('January 25 2019', 'CLE', 'MIA')
# ('January 25 2019', 'DAL', 'DET')
# ('January 25 2019', 'DEN', 'PHO')
# ('January 25 2019', 'HOU', 'TOR')
# ('January 25 2019', 'MEM', 'SAC')
# ('January 25 2019', 'MIL', 'CHO')
# ('January 25 2019', 'ORL', 'WAS')
# ('January 25 2019', 'UTA', 'MIN')
# ('January 26 2019', 'BOS', 'GSW')
# ('January 26 2019', 'DEN', 'PHI')
# ('January 26 2019', 'MEM', 'IND')
# ('January 26 2019', 'NOP', 'SAS')
# ('January 26 2019', 'POR', 'ATL')
# ('January 27 2019', 'CHI', 'CLE')
# ('January 27 2019', 'DAL', 'TOR')
# ('January 27 2019', 'HOU', 'ORL')
# ('January 27 2019', 'LAC', 'SAC')
# ('January 27 2019', 'LAL', 'PHO')
# ('January 27 2019', 'MIN', 'UTA')
# ('January 27 2019', 'NYK', 'MIA')
# ('January 27 2019', 'OKC', 'MIL')
# ('January 27 2019', 'SAS', 'WAS')
# ('January 28 2019', 'BOS', 'BRK')
# ('January 28 2019', 'CHO', 'NYK')
# ('January 28 2019', 'IND', 'GSW')
# ('January 28 2019', 'LAC', 'ATL')
# ('January 28 2019', 'MEM', 'DEN')
# ('January 29 2019', 'BRK', 'CHI')
# ('January 29 2019', 'CLE', 'WAS')
# ('January 29 2019', 'DET', 'MIL')
# ('January 29 2019', 'HOU', 'NOP')
# ('January 29 2019', 'LAL', 'PHI')
# ('January 29 2019', 'ORL', 'OKC')
# ('January 29 2019', 'SAS', 'PHO')
# ('January 3 2019', 'GSW', 'HOU')
# ('January 3 2019', 'SAC', 'DEN')
# ('January 3 2019', 'SAS', 'TOR')
# ('January 30 2019', 'BOS', 'CHO')
# ('January 30 2019', 'MIA', 'CHI')
# ('January 30 2019', 'MIN', 'MEM')
# ('January 30 2019', 'NOP', 'DEN')
# ('January 30 2019', 'NYK', 'DAL')
# ('January 30 2019', 'POR', 'UTA')
# ('January 30 2019', 'SAC', 'ATL')
# ('January 30 2019', 'WAS', 'IND')
# ('January 31 2019', 'DET', 'DAL')
# ('January 31 2019', 'GSW', 'PHI')
# ('January 31 2019', 'LAC', 'LAL')
# ('January 31 2019', 'ORL', 'IND')
# ('January 31 2019', 'SAS', 'BRK')
# ('January 31 2019', 'TOR', 'MIL')
# ('January 4 2019', 'BOS', 'DAL')
# ('January 4 2019', 'CHI', 'IND')
# ('January 4 2019', 'CLE', 'UTA')
# ('January 4 2019', 'LAL', 'NYK')
# ('January 4 2019', 'MEM', 'BRK')
# ('January 4 2019', 'MIA', 'WAS')
# ('January 4 2019', 'MIL', 'ATL')
# ('January 4 2019', 'MIN', 'ORL')
# ('January 4 2019', 'PHO', 'LAC')
# ('January 4 2019', 'POR', 'OKC')
# ('January 5 2019', 'CLE', 'NOP')
# ('January 5 2019', 'DEN', 'CHO')
# ('January 5 2019', 'DET', 'UTA')
# ('January 5 2019', 'MIL', 'TOR')
# ('January 5 2019', 'PHI', 'DAL')
# ('January 5 2019', 'POR', 'HOU')
# ('January 5 2019', 'SAC', 'GSW')
# ('January 5 2019', 'SAS', 'MEM')
# ('January 6 2019', 'ATL', 'MIA')
# ('January 6 2019', 'CHI', 'BRK')
# ('January 6 2019', 'LAC', 'ORL')
# ('January 6 2019', 'MIN', 'LAL')
# ('January 6 2019', 'OKC', 'WAS')
# ('January 6 2019', 'PHO', 'CHO')
# ('January 6 2019', 'TOR', 'IND')
# ('January 7 2019', 'BOS', 'BRK')
# ('January 7 2019', 'DAL', 'LAL')
# ('January 7 2019', 'DET', 'SAS')
# ('January 7 2019', 'HOU', 'DEN')
# ('January 7 2019', 'MIL', 'UTA')
# ('January 7 2019', 'NOP', 'MEM')
# ('January 7 2019', 'POR', 'NYK')
# ('January 7 2019', 'SAC', 'ORL')
# ('January 8 2019', 'CLE', 'IND')
# ('January 8 2019', 'GSW', 'NYK')
# ('January 8 2019', 'LAC', 'CHO')
# ('January 8 2019', 'MIA', 'DEN')
# ('January 8 2019', 'OKC', 'MIN')
# ('January 8 2019', 'PHI', 'WAS')
# ('January 8 2019', 'PHO', 'SAC')
# ('January 8 2019', 'TOR', 'ATL')
# ('January 9 2019', 'BOS', 'IND')
# ('January 9 2019', 'BRK', 'ATL')
# ('January 9 2019', 'DAL', 'PHO')
# ('January 9 2019', 'HOU', 'MIL')
# ('January 9 2019', 'LAL', 'DET')
# ('January 9 2019', 'MEM', 'SAS')
# ('January 9 2019', 'NOP', 'CLE')
# ('January 9 2019', 'POR', 'CHI')
# ('January 9 2019', 'UTA', 'ORL')
# ('January 9 2019', 'WAS', 'PHI')
# ('June 10 2019', 'TOR', 'GSW')
# ('June 13 2019', 'GSW', 'TOR')
# ('June 2 2019', 'TOR', 'GSW')
# ('June 5 2019', 'GSW', 'TOR')
# ('June 7 2019', 'GSW', 'TOR')
# ('March 1 2019', 'ATL', 'CHI')
# ('March 1 2019', 'BOS', 'WAS')
# ('March 1 2019', 'BRK', 'CHO')
# ('March 1 2019', 'LAL', 'MIL')
# ('March 1 2019', 'PHO', 'NOP')
# ('March 1 2019', 'SAC', 'LAC')
# ('March 1 2019', 'TOR', 'POR')
# ('March 10 2019', 'ATL', 'NOP')
# ('March 10 2019', 'DAL', 'HOU')
# ('March 10 2019', 'DET', 'CHI')
# ('March 10 2019', 'GSW', 'PHO')
# ('March 10 2019', 'MEM', 'ORL')
# ('March 10 2019', 'MIA', 'TOR')
# ('March 10 2019', 'MIN', 'NYK')
# ('March 10 2019', 'PHI', 'IND')
# ('March 10 2019', 'SAS', 'MIL')
# ('March 11 2019', 'BRK', 'DET')
# ('March 11 2019', 'CLE', 'TOR')
# ('March 11 2019', 'HOU', 'CHO')
# ('March 11 2019', 'LAC', 'BOS')
# ('March 11 2019', 'UTA', 'OKC')
# ('March 11 2019', 'WAS', 'SAC')
# ('March 12 2019', 'CHI', 'LAL')
# ('March 12 2019', 'DAL', 'SAS')
# ('March 12 2019', 'DEN', 'MIN')
# ('March 12 2019', 'IND', 'NYK')
# ('March 12 2019', 'LAC', 'POR')
# ('March 12 2019', 'NOP', 'MIL')
# ('March 12 2019', 'PHI', 'CLE')
# ('March 13 2019', 'ATL', 'MEM')
# ('March 13 2019', 'HOU', 'GSW')
# ('March 13 2019', 'MIA', 'DET')
# ('March 13 2019', 'OKC', 'BRK')
# ('March 13 2019', 'PHO', 'UTA')
# ('March 13 2019', 'WAS', 'ORL')
# ('March 14 2019', 'BOS', 'SAC')
# ('March 14 2019', 'DEN', 'DAL')
# ('March 14 2019', 'IND', 'OKC')
# ('March 14 2019', 'ORL', 'CLE')
# ('March 14 2019', 'TOR', 'LAL')
# ('March 14 2019', 'UTA', 'MIN')
# ('March 15 2019', 'DET', 'LAL')
# ('March 15 2019', 'HOU', 'PHO')
# ('March 15 2019', 'LAC', 'CHI')
# ('March 15 2019', 'MIA', 'MIL')
# ('March 15 2019', 'NOP', 'POR')
# ('March 15 2019', 'PHI', 'SAC')
# ('March 15 2019', 'SAS', 'NYK')
# ('March 15 2019', 'WAS', 'CHO')
# ('March 16 2019', 'BOS', 'ATL')
# ('March 16 2019', 'DAL', 'CLE')
# ('March 16 2019', 'DEN', 'IND')
# ('March 16 2019', 'NOP', 'PHO')
# ('March 16 2019', 'OKC', 'GSW')
# ('March 16 2019', 'SAS', 'POR')
# ('March 16 2019', 'UTA', 'BRK')
# ('March 16 2019', 'WAS', 'MEM')
# ('March 17 2019', 'DET', 'TOR')
# ('March 17 2019', 'HOU', 'MIN')
# ('March 17 2019', 'LAC', 'BRK')
# ('March 17 2019', 'MIA', 'CHO')
# ('March 17 2019', 'MIL', 'PHI')
# ('March 17 2019', 'NYK', 'LAL')
# ('March 17 2019', 'ORL', 'ATL')
# ('March 17 2019', 'SAC', 'CHI')
# ('March 18 2019', 'BOS', 'DEN')
# ('March 18 2019', 'CLE', 'DET')
# ('March 18 2019', 'DAL', 'NOP')
# ('March 18 2019', 'OKC', 'MIA')
# ('March 18 2019', 'PHO', 'CHI')
# ('March 18 2019', 'POR', 'IND')
# ('March 18 2019', 'SAS', 'GSW')
# ('March 18 2019', 'TOR', 'NYK')
# ('March 18 2019', 'WAS', 'UTA')
# ('March 19 2019', 'ATL', 'HOU')
# ('March 19 2019', 'CHO', 'PHI')
# ('March 19 2019', 'LAC', 'IND')
# ('March 19 2019', 'MIL', 'LAL')
# ('March 19 2019', 'MIN', 'GSW')
# ('March 19 2019', 'SAC', 'BRK')
# ('March 2 2019', 'CLE', 'DET')
# ('March 2 2019', 'DAL', 'MEM')
# ('March 2 2019', 'DEN', 'NOP')
# ('March 2 2019', 'IND', 'ORL')
# ('March 2 2019', 'MIA', 'BRK')
# ('March 2 2019', 'PHI', 'GSW')
# ('March 2 2019', 'PHO', 'LAL')
# ('March 2 2019', 'SAS', 'OKC')
# ('March 2 2019', 'UTA', 'MIL')
# ('March 20 2019', 'CHI', 'WAS')
# ('March 20 2019', 'CLE', 'MIL')
# ('March 20 2019', 'MEM', 'HOU')
# ('March 20 2019', 'NYK', 'UTA')
# ('March 20 2019', 'OKC', 'TOR')
# ('March 20 2019', 'ORL', 'NOP')
# ('March 20 2019', 'PHI', 'BOS')
# ('March 20 2019', 'POR', 'DAL')
# ('March 20 2019', 'SAS', 'MIA')
# ('March 21 2019', 'ATL', 'UTA')
# ('March 21 2019', 'CHO', 'MIN')
# ('March 21 2019', 'GSW', 'IND')
# ('March 21 2019', 'PHO', 'DET')
# ('March 21 2019', 'SAC', 'DAL')
# ('March 21 2019', 'WAS', 'DEN')
# ('March 22 2019', 'CLE', 'LAC')
# ('March 22 2019', 'HOU', 'SAS')
# ('March 22 2019', 'LAL', 'BRK')
# ('March 22 2019', 'MIL', 'MIA')
# ('March 22 2019', 'NYK', 'DEN')
# ('March 22 2019', 'ORL', 'MEM')
# ('March 22 2019', 'TOR', 'OKC')
# ('March 23 2019', 'ATL', 'PHI')
# ('March 23 2019', 'CHI', 'UTA')
# ('March 23 2019', 'CHO', 'BOS')
# ('March 23 2019', 'GSW', 'DAL')
# ('March 23 2019', 'MEM', 'MIN')
# ('March 23 2019', 'POR', 'DET')
# ('March 23 2019', 'SAC', 'PHO')
# ('March 23 2019', 'WAS', 'MIA')
# ('March 24 2019', 'BOS', 'SAS')
# ('March 24 2019', 'GSW', 'DET')
# ('March 24 2019', 'IND', 'DEN')
# ('March 24 2019', 'LAL', 'SAC')
# ('March 24 2019', 'MIL', 'CLE')
# ('March 24 2019', 'NOP', 'HOU')
# ('March 24 2019', 'NYK', 'LAC')
# ('March 24 2019', 'TOR', 'CHO')
# ('March 25 2019', 'MEM', 'OKC')
# ('March 25 2019', 'ORL', 'PHI')
# ('March 25 2019', 'POR', 'BRK')
# ('March 25 2019', 'UTA', 'PHO')
# ('March 26 2019', 'CHO', 'SAS')
# ('March 26 2019', 'CLE', 'BOS')
# ('March 26 2019', 'DAL', 'SAC')
# ('March 26 2019', 'DEN', 'DET')
# ('March 26 2019', 'LAL', 'WAS')
# ('March 26 2019', 'MIA', 'ORL')
# ('March 26 2019', 'MIL', 'HOU')
# ('March 26 2019', 'MIN', 'LAC')
# ('March 26 2019', 'NOP', 'ATL')
# ('March 26 2019', 'TOR', 'CHI')
# ('March 27 2019', 'CHI', 'POR')
# ('March 27 2019', 'MEM', 'GSW')
# ('March 27 2019', 'OKC', 'IND')
# ('March 27 2019', 'PHO', 'WAS')
# ('March 27 2019', 'UTA', 'LAL')
# ('March 28 2019', 'DET', 'ORL')
# ('March 28 2019', 'HOU', 'DEN')
# ('March 28 2019', 'MIA', 'DAL')
# ('March 28 2019', 'MIL', 'LAC')
# ('March 28 2019', 'NOP', 'SAC')
# ('March 28 2019', 'NYK', 'TOR')
# ('March 28 2019', 'PHI', 'BRK')
# ('March 28 2019', 'SAS', 'CLE')
# ('March 29 2019', 'ATL', 'POR')
# ('March 29 2019', 'BOS', 'IND')
# ('March 29 2019', 'LAL', 'CHO')
# ('March 29 2019', 'MIN', 'GSW')
# ('March 29 2019', 'OKC', 'DEN')
# ('March 29 2019', 'UTA', 'WAS')
# ('March 3 2019', 'BOS', 'HOU')
# ('March 3 2019', 'CHI', 'ATL')
# ('March 3 2019', 'CHO', 'POR')
# ('March 3 2019', 'CLE', 'ORL')
# ('March 3 2019', 'DET', 'TOR')
# ('March 3 2019', 'LAC', 'NYK')
# ('March 3 2019', 'OKC', 'MEM')
# ('March 3 2019', 'WAS', 'MIN')
# ('March 30 2019', 'BRK', 'BOS')
# ('March 30 2019', 'CHI', 'TOR')
# ('March 30 2019', 'DET', 'POR')
# ('March 30 2019', 'HOU', 'SAC')
# ('March 30 2019', 'IND', 'ORL')
# ('March 30 2019', 'LAC', 'CLE')
# ('March 30 2019', 'MIN', 'PHI')
# ('March 30 2019', 'NYK', 'MIA')
# ('March 30 2019', 'PHO', 'MEM')
# ('March 31 2019', 'ATL', 'MIL')
# ('March 31 2019', 'DEN', 'WAS')
# ('March 31 2019', 'GSW', 'CHO')
# ('March 31 2019', 'LAC', 'MEM')
# ('March 31 2019', 'NOP', 'LAL')
# ('March 31 2019', 'OKC', 'DAL')
# ('March 31 2019', 'SAS', 'SAC')
# ('March 4 2019', 'BRK', 'DAL')
# ('March 4 2019', 'LAL', 'LAC')
# ('March 4 2019', 'MIA', 'ATL')
# ('March 4 2019', 'PHO', 'MIL')
# ('March 4 2019', 'SAC', 'NYK')
# ('March 4 2019', 'SAS', 'DEN')
# ('March 4 2019', 'UTA', 'NOP')
# ('March 5 2019', 'GSW', 'BOS')
# ('March 5 2019', 'IND', 'CHI')
# ('March 5 2019', 'MEM', 'POR')
# ('March 5 2019', 'MIN', 'OKC')
# ('March 5 2019', 'PHI', 'ORL')
# ('March 5 2019', 'TOR', 'HOU')
# ('March 6 2019', 'ATL', 'SAS')
# ('March 6 2019', 'BRK', 'CLE')
# ('March 6 2019', 'CHI', 'PHI')
# ('March 6 2019', 'CHO', 'MIA')
# ('March 6 2019', 'DET', 'MIN')
# ('March 6 2019', 'LAL', 'DEN')
# ('March 6 2019', 'NOP', 'UTA')
# ('March 6 2019', 'PHO', 'NYK')
# ('March 6 2019', 'SAC', 'BOS')
# ('March 6 2019', 'WAS', 'DAL')
# ('March 7 2019', 'MIL', 'IND')
# ('March 7 2019', 'POR', 'OKC')
# ('March 8 2019', 'CHI', 'DET')
# ('March 8 2019', 'CHO', 'WAS')
# ('March 8 2019', 'GSW', 'DEN')
# ('March 8 2019', 'HOU', 'PHI')
# ('March 8 2019', 'LAC', 'OKC')
# ('March 8 2019', 'MEM', 'UTA')
# ('March 8 2019', 'MIA', 'CLE')
# ('March 8 2019', 'NOP', 'TOR')
# ('March 8 2019', 'ORL', 'DAL')
# ('March 9 2019', 'ATL', 'BRK')
# ('March 9 2019', 'LAL', 'BOS')
# ('March 9 2019', 'MIL', 'CHO')
# ('March 9 2019', 'MIN', 'WAS')
# ('March 9 2019', 'NYK', 'SAC')
# ('March 9 2019', 'POR', 'PHO')
# ('May 1 2019', 'DEN', 'POR')
# ('May 10 2019', 'HOU', 'GSW')
# ('May 12 2019', 'DEN', 'POR')
# ('May 12 2019', 'TOR', 'PHI')
# ('May 14 2019', 'GSW', 'POR')
# ('May 15 2019', 'MIL', 'TOR')
# ('May 16 2019', 'GSW', 'POR')
# ('May 17 2019', 'MIL', 'TOR')
# ('May 18 2019', 'POR', 'GSW')
# ('May 19 2019', 'TOR', 'MIL')
# ('May 2 2019', 'PHI', 'TOR')
# ('May 20 2019', 'POR', 'GSW')
# ('May 21 2019', 'TOR', 'MIL')
# ('May 23 2019', 'MIL', 'TOR')
# ('May 25 2019', 'TOR', 'MIL')
# ('May 3 2019', 'BOS', 'MIL')
# ('May 3 2019', 'POR', 'DEN')
# ('May 30 2019', 'TOR', 'GSW')
# ('May 4 2019', 'HOU', 'GSW')
# ('May 5 2019', 'PHI', 'TOR')
# ('May 5 2019', 'POR', 'DEN')
# ('May 6 2019', 'BOS', 'MIL')
# ('May 6 2019', 'HOU', 'GSW')
# ('May 7 2019', 'DEN', 'POR')
# ('May 7 2019', 'TOR', 'PHI')
# ('May 8 2019', 'GSW', 'HOU')
# ('May 8 2019', 'MIL', 'BOS')
# ('May 9 2019', 'PHI', 'TOR')
# ('May 9 2019', 'POR', 'DEN')
# ('November 1 2018', 'ATL', 'SAC')
# ('November 1 2018', 'BOS', 'MIL')
# ('November 1 2018', 'CHO', 'OKC')
# ('November 1 2018', 'CLE', 'DEN')
# ('November 1 2018', 'PHI', 'LAC')
# ('November 1 2018', 'POR', 'NOP')
# ('November 10 2018', 'CHI', 'CLE')
# ('November 10 2018', 'DAL', 'OKC')
# ('November 10 2018', 'GSW', 'BRK')
# ('November 10 2018', 'LAC', 'MIL')
# ('November 10 2018', 'MEM', 'PHI')
# ('November 10 2018', 'MIA', 'WAS')
# ('November 10 2018', 'NOP', 'PHO')
# ('November 10 2018', 'SAC', 'LAL')
# ('November 10 2018', 'SAS', 'HOU')
# ('November 10 2018', 'TOR', 'NYK')
# ('November 11 2018', 'DEN', 'MIL')
# ('November 11 2018', 'DET', 'CHO')
# ('November 11 2018', 'HOU', 'IND')
# ('November 11 2018', 'LAL', 'ATL')
# ('November 11 2018', 'NYK', 'ORL')
# ('November 11 2018', 'POR', 'BOS')
# ('November 12 2018', 'CHI', 'DAL')
# ('November 12 2018', 'LAC', 'GSW')
# ('November 12 2018', 'MEM', 'UTA')
# ('November 12 2018', 'MIA', 'PHI')
# ('November 12 2018', 'MIN', 'BRK')
# ('November 12 2018', 'OKC', 'PHO')
# ('November 12 2018', 'SAC', 'SAS')
# ('November 12 2018', 'TOR', 'NOP')
# ('November 12 2018', 'WAS', 'ORL')
# ('November 13 2018', 'CLE', 'CHO')
# ('November 13 2018', 'DEN', 'HOU')
# ('November 13 2018', 'GSW', 'ATL')
# ('November 14 2018', 'BOS', 'CHI')
# ('November 14 2018', 'BRK', 'MIA')
# ('November 14 2018', 'DAL', 'UTA')
# ('November 14 2018', 'LAL', 'POR')
# ('November 14 2018', 'MIL', 'MEM')
# ('November 14 2018', 'MIN', 'NOP')
# ('November 14 2018', 'OKC', 'NYK')
# ('November 14 2018', 'ORL', 'PHI')
# ('November 14 2018', 'PHO', 'SAS')
# ('November 14 2018', 'TOR', 'DET')
# ('November 14 2018', 'WAS', 'CLE')
# ('November 15 2018', 'DEN', 'ATL')
# ('November 15 2018', 'HOU', 'GSW')
# ('November 15 2018', 'LAC', 'SAS')
# ('November 16 2018', 'BOS', 'TOR')
# ('November 16 2018', 'IND', 'MIA')
# ('November 16 2018', 'MEM', 'SAC')
# ('November 16 2018', 'MIL', 'CHI')
# ('November 16 2018', 'MIN', 'POR')
# ('November 16 2018', 'NOP', 'NYK')
# ('November 16 2018', 'PHI', 'UTA')
# ('November 16 2018', 'WAS', 'BRK')
# ('November 17 2018', 'BOS', 'UTA')
# ('November 17 2018', 'BRK', 'LAC')
# ('November 17 2018', 'CHI', 'TOR')
# ('November 17 2018', 'CHO', 'PHI')
# ('November 17 2018', 'DAL', 'GSW')
# ('November 17 2018', 'HOU', 'SAC')
# ('November 17 2018', 'IND', 'ATL')
# ('November 17 2018', 'NOP', 'DEN')
# ('November 17 2018', 'ORL', 'LAL')
# ('November 17 2018', 'PHO', 'OKC')
# ('November 18 2018', 'MIA', 'LAL')
# ('November 18 2018', 'MIN', 'MEM')
# ('November 18 2018', 'ORL', 'NYK')
# ('November 18 2018', 'SAS', 'GSW')
# ('November 18 2018', 'WAS', 'POR')
# ('November 19 2018', 'ATL', 'LAC')
# ('November 19 2018', 'CHO', 'BOS')
# ('November 19 2018', 'DET', 'CLE')
# ('November 19 2018', 'IND', 'UTA')
# ('November 19 2018', 'MEM', 'DAL')
# ('November 19 2018', 'MIL', 'DEN')
# ('November 19 2018', 'NOP', 'SAS')
# ('November 19 2018', 'PHI', 'PHO')
# ('November 19 2018', 'SAC', 'OKC')
# ('November 2 2018', 'BRK', 'HOU')
# ('November 2 2018', 'CHI', 'IND')
# ('November 2 2018', 'DAL', 'NYK')
# ('November 2 2018', 'GSW', 'MIN')
# ('November 2 2018', 'ORL', 'LAC')
# ('November 2 2018', 'PHO', 'TOR')
# ('November 2 2018', 'UTA', 'MEM')
# ('November 2 2018', 'WAS', 'OKC')
# ('November 20 2018', 'MIA', 'BRK')
# ('November 20 2018', 'NYK', 'POR')
# ('November 20 2018', 'ORL', 'TOR')
# ('November 20 2018', 'WAS', 'LAC')
# ('November 21 2018', 'ATL', 'TOR')
# ('November 21 2018', 'BOS', 'NYK')
# ('November 21 2018', 'CHI', 'PHO')
# ('November 21 2018', 'CHO', 'IND')
# ('November 21 2018', 'CLE', 'LAL')
# ('November 21 2018', 'DAL', 'BRK')
# ('November 21 2018', 'GSW', 'OKC')
# ('November 21 2018', 'HOU', 'DET')
# ('November 21 2018', 'MIL', 'POR')
# ('November 21 2018', 'MIN', 'DEN')
# ('November 21 2018', 'PHI', 'NOP')
# ('November 21 2018', 'SAS', 'MEM')
# ('November 21 2018', 'UTA', 'SAC')
# ('November 23 2018', 'ATL', 'BOS')
# ('November 23 2018', 'BRK', 'MIN')
# ('November 23 2018', 'CHI', 'MIA')
# ('November 23 2018', 'DEN', 'ORL')
# ('November 23 2018', 'DET', 'HOU')
# ('November 23 2018', 'GSW', 'POR')
# ('November 23 2018', 'IND', 'SAS')
# ('November 23 2018', 'LAC', 'MEM')
# ('November 23 2018', 'LAL', 'UTA')
# ('November 23 2018', 'MIL', 'PHO')
# ('November 23 2018', 'NYK', 'NOP')
# ('November 23 2018', 'OKC', 'CHO')
# ('November 23 2018', 'PHI', 'CLE')
# ('November 23 2018', 'TOR', 'WAS')
# ('November 24 2018', 'CLE', 'HOU')
# ('November 24 2018', 'DAL', 'BOS')
# ('November 24 2018', 'GSW', 'SAC')
# ('November 24 2018', 'MIL', 'SAS')
# ('November 24 2018', 'MIN', 'CHI')
# ('November 24 2018', 'OKC', 'DEN')
# ('November 24 2018', 'WAS', 'NOP')
# ('November 25 2018', 'ATL', 'CHO')
# ('November 25 2018', 'BRK', 'PHI')
# ('November 25 2018', 'DET', 'PHO')
# ('November 25 2018', 'LAL', 'ORL')
# ('November 25 2018', 'MEM', 'NYK')
# ('November 25 2018', 'POR', 'LAC')
# ('November 25 2018', 'SAC', 'UTA')
# ('November 25 2018', 'TOR', 'MIA')
# ('November 26 2018', 'CHI', 'SAS')
# ('November 26 2018', 'CHO', 'MIL')
# ('November 26 2018', 'CLE', 'MIN')
# ('November 26 2018', 'GSW', 'ORL')
# ('November 26 2018', 'NOP', 'BOS')
# ('November 26 2018', 'UTA', 'IND')
# ('November 26 2018', 'WAS', 'HOU')
# ('November 27 2018', 'DEN', 'LAL')
# ('November 27 2018', 'DET', 'NYK')
# ('November 27 2018', 'MEM', 'TOR')
# ('November 27 2018', 'MIA', 'ATL')
# ('November 27 2018', 'PHO', 'IND')
# ('November 28 2018', 'BRK', 'UTA')
# ('November 28 2018', 'CHO', 'ATL')
# ('November 28 2018', 'HOU', 'DAL')
# ('November 28 2018', 'LAC', 'PHO')
# ('November 28 2018', 'MIL', 'CHI')
# ('November 28 2018', 'MIN', 'SAS')
# ('November 28 2018', 'NOP', 'WAS')
# ('November 28 2018', 'OKC', 'CLE')
# ('November 28 2018', 'PHI', 'NYK')
# ('November 28 2018', 'POR', 'ORL')
# ('November 29 2018', 'LAL', 'IND')
# ('November 29 2018', 'SAC', 'LAC')
# ('November 29 2018', 'TOR', 'GSW')
# ('November 3 2018', 'ATL', 'MIA')
# ('November 3 2018', 'CHI', 'HOU')
# ('November 3 2018', 'CHO', 'CLE')
# ('October 27 2018', 'MIL', 'ORL')
# ('October 27 2018', 'NOP', 'UTA')
# ('October 27 2018', 'PHI', 'CHO')
# ('October 27 2018', 'SAS', 'LAL')
# ('October 28 2018', 'BRK', 'GSW')
# ('October 28 2018', 'DAL', 'UTA')
# ('October 28 2018', 'LAC', 'WAS')
# ('October 28 2018', 'OKC', 'PHO')
# ('October 29 2018', 'CHI', 'GSW')
# ('October 29 2018', 'DEN', 'NOP')
# ('October 29 2018', 'IND', 'POR')
# ('October 29 2018', 'MIA', 'SAC')
# ('October 29 2018', 'MIL', 'TOR')
# ('October 29 2018', 'MIN', 'LAL')
# ('October 29 2018', 'NYK', 'BRK')
# ('October 29 2018', 'PHI', 'ATL')
# ('October 29 2018', 'SAS', 'DAL')
# ('October 30 2018', 'BOS', 'DET')
# ('October 30 2018', 'CHO', 'MIA')
# ('October 30 2018', 'CLE', 'ATL')
# ('October 30 2018', 'HOU', 'POR')
# ('October 30 2018', 'MEM', 'WAS')
# ('October 30 2018', 'OKC', 'LAC')
# ('October 30 2018', 'ORL', 'SAC')
# ('October 30 2018', 'TOR', 'PHI')
# ('October 31 2018', 'BRK', 'DET')
# ('October 31 2018', 'CHI', 'DEN')
# ('October 31 2018', 'GSW', 'NOP')
# ('October 31 2018', 'LAL', 'DAL')
# ('October 31 2018', 'MIN', 'UTA')
# ('October 31 2018', 'NYK', 'IND')
# ('October 31 2018', 'PHO', 'SAS')

# %%
import json
from datetime import datetime
player_event_dict = {
    # Type, Outcome, Relation, Attr
    "TryPt": (["3-pt jump shot", "2-pt jump shot", "2-pt hook shot", "2-pt layup", "2-pt tip-in", "2-pt dunk"], ["make", "miss"], 
              ["AssistedBy", "BlockedBy"], ["Dist"]),
    "FreeThrow": ([], ["make", "miss"], ["Fouler"], []),
    "Turnover": (
        ["3 sec", "5 sec", "8 sec", "back court", "bad pass", "dbl dribble", "discontinued dribble", "illegal assist", "inbound",
         "lane violation", "lost ball", "off goaltending", "offensive foul", "out of bounds lost ball", "palming", "shot clock", 
         "step out of bounds", "traveling", "turnover"],
        [], ["StolenBy"], []),
    "Rebound": (["defensive", "offensive"], [], [], []),
    "Foul": (
        ["away from play", "clear path", "def 3 sec tech", "flagrant", "loose ball", "offensive", 
         "personal", "personal take", "shooting", "technical"],
        [], ["Fouled"], []
    ),
    "Enter": ([], [], ["Replace"], [])
}
player_relations = ["Jumpball", "Replace", "Assist", "Steal", "Block"]
def make_event(eName:str, ePlayer:str, eType:str=None, eOut:str=None, eRels:dict=None, eAttrs:dict=None):
    event = {}
    assert eName in player_event_dict, "Event name unrecognized, event name:{}".format(eName)
    event["name"] = eName
    event_metadata = player_event_dict[eName]
    event["player"] = ePlayer
    if eType is not None:
        assert eType in event_metadata[0], "Event type unrecognized, event:{}, type:{}".format(eName, eType)
    else:
        assert len(event_metadata[0]) == 0, "Event type missing"
    event["type"] = eType
    
    if eOut is not None:
        assert eOut in event_metadata[1], "Event outcome unrecognized"
    else:
        assert len(event_metadata[1]) == 0, "Event outcome missing"
    event["outcome"] = eOut
    
    # Event relations may not be essential
    if eRels is not None: 
        for rel in eRels:
            assert rel in event_metadata[2], "Event relation unrecognized, event:{}, relation:{}".format(eName, eRels)
    event["relations"] = eRels
    
    if eAttrs is not None:
        for attr in eAttrs:
            assert attr in event_metadata[3], "Event attributes unrecognized"
    event["attributes"] = eAttrs
    return event

class GameExtractor:
    def __init__(self):
        self.current_game = None
        self.player_dict = {}
        self.team_dict = {}
        self.events = []
        
    
    def read_game(self, game_record):
        game_info = {
            "HomeTeam": game_record.iloc[0]["HomeTeam"],
            "AwayTeam": game_record.iloc[0]["AwayTeam"],
            "WinningTeam": game_record.iloc[0]["WinningTeam"],
        }
        
        
        '''
        Code below is to eliminate contradictory player names
        Since some of the player name is wrong in suffix
        Like J. Embiid - BOS (Should be J. Embiid - PHI, the team name is wrongly placed)
        '''
        player_dict = [{}, {}]
        player_cols = ["Shooter", "Assister", "Blocker", "Fouler", "Fouled", "Rebounder", "TurnoverPlayer", "TurnoverCauser",
                       "JumpballAwayPlayer", "JumpballHomePlayer"]
        for _, row in game_record.iterrows():
            for col in player_cols:
                player = row[col]
                if player == "" or " - " not in player or player.startswith("Team"):
                    continue
                player_name, player_team = player.split(' - ')
                if player_team == game_info["HomeTeam"]:
                    cur_dict = player_dict[0]
                elif player_team == game_info["AwayTeam"]:
                    cur_dict = player_dict[1]
                else:
                    print("Invalid player encountered")
                    continue
                if player_name not in cur_dict:
                    cur_dict[player_name] = 0
                cur_dict[player_name] += 1
        
        '''
        Assume the wrong labeled player names is less than right labeled ones
        '''
        true_player_dict = {}
        for key in player_dict[0]:
            if key not in player_dict[1] or player_dict[0][key] >= player_dict[1][key]:
                true_player_dict[key] = key + " - " + game_info["HomeTeam"]
            else:
                true_player_dict[key] = key + " - " + game_info["AwayTeam"]
        for key in player_dict[1]:
            if key not in player_dict[0]:
                true_player_dict[key] = key + " - " + game_info["AwayTeam"]
        '''
        Replaces the wrong names
        '''
        for _, row in game_record.iterrows():
            for col in player_cols:
                player = row[col]
                if player == "" or " - " not in player or player.startswith("Team"):
                    continue
                player_name, player_team = player.split(' - ')
                row[col] = true_player_dict[player_name]
        
                    
        events = []
        for _, row in game_record.iterrows():
            event = self.read_event(row)
            if event is not None:
                events.append(event)
        # Handle free throw events
        for i in range(len(events)):
            if events[i]["name"] == "Foul":
                fouler = events[i]["player"]
                i += 1
                if i >= len(events):
                    break
                # Consider there would be some player switch during free throws
                while events[i]["name"] == "FreeThrow" or events[i]["name"] == "Enter":
                    if events[i]["name"] == "FreeThrow":
                        events[i]["relations"] = {"Fouler": fouler}
                    i += 1
                    if i >= len(events):
                        break
        
        game_info["events"] = events
        game_info["players"] = list(set([event["player"] for event in events]))
        return game_info

    def read_event(self, row):
        play = row["HomePlay"] + row["AwayPlay"]
        if "makes" in play or "misses" in play:
            if "pt" in play:
                rel = None
                if row["Assister"] != "":
                    rel = {"AssistedBy": row["Assister"]}
                if row["Blocker"] != "":
                    rel = {"BlockedBy": row["Blocker"]}
                event = make_event("TryPt", row["Shooter"], row["ShotType"], row["ShotOutcome"], rel, 
                                   {"Dist": int(row["ShotDist"])})
            elif "free throw" in play:
                event = make_event("FreeThrow", row["FreeThrowShooter"], None, row["FreeThrowOutcome"], None, None)
        elif "rebound" in play:
            # Seems when the first free throw finished, always have a "Offensive rebound by Team, so just ignore that"
            if "Team" in play:
                return None
            event = make_event("Rebound", row["Rebounder"], row["ReboundType"], None, None, None)
        elif "Turnover" in play:
            rel = None
            if row["TurnoverCause"] == "steal":
                rel = {"StolenBy": row["TurnoverCauser"]}
            event = make_event("Turnover", row["TurnoverPlayer"], row["TurnoverType"], None, rel, None)
        elif "foul" in play:
            rel = {"Fouled": row["Fouled"]}
            event = make_event("Foul", row["Fouler"], row["FoulType"], None, rel, None)
        elif "enters" in play:
            rel = {"Replace": row["LeaveGame"]}
            event = make_event("Enter", row["EnterGame"], None, None, rel, None)
        else:
            event = None
        return event
    
    def extract_all(self, pbp_dict:dict, extract_path:str):
        n_games = len(pbp_dict)
        print("Total Games: {}".format(n_games))
        for i, key in enumerate(pbp_dict):
            key_name = datetime.strptime(key[0], "%B %d %Y").strftime("%Y%m%d") + "-" + key[1] + "-" + key[2]
            print("Parse {}th game".format(i))
            game = self.read_game(pbp_dict[key])
            with open(extract_path + key_name + ".json", "w") as f:
                json.dump(game, f)
                print("Saved {}th game".format(i))

# %%
reader = GameExtractor()

# %%
record = pbp_dict[('April 1 2019', 'BOS', 'MIA')]

# %%
game = reader.read_game(record)

# %%
game
# Out:
# {'HomeTeam': 'BOS',
#  'AwayTeam': 'MIA',
#  'WinningTeam': 'BOS',
#  'events': [{'name': 'TryPt',
#    'player': 'J. Tatum - BOS',
#    'type': '3-pt jump shot',
#    'outcome': 'miss',
#    'relations': None,
#    'attributes': {'Dist': 23}},
#   {'name': 'Rebound',
#    'player': 'D. Jones - MIA',
#    'type': 'defensive',
#    'outcome': None,
#    'relations': None,
#    'attributes': None},
#   {'name': 'TryPt',
#    'player': 'K. Olynyk - MIA',
#    'type': '3-pt jump shot',
#    'outcome': 'miss',
#    'relations': None,
#    'attributes': {'Dist': 26}},
#   {'name': 'Rebound',
#    'player': 'K. Irving - BOS',
#    'type': 'defensive',
#    'outcome': None,
#    'relations': None,
#    'attributes': None},
#   {'name': 'TryPt',
#    'player': 'J. Tatum - BOS',
#    'type': '2-pt jump shot',
#    'outcome': 'miss',
#    'relations': None,
#    'attributes': {'Dist': 20}},
#   {'name': 'Rebound',
#    'player': 'M. Smart - BOS',
#    'type': 'offensive',
#    'outcome': None,
#    'relations': None,
#    'attributes': None},
#   {'name': 'TryPt',
#    'player': 'M. Smart - BOS',
#    'type': '2-pt layup',
#    'outcome': 'make',
#    'relations': None,
#    'attributes': {'Dist': 1}},
#   {'name': 'TryPt',
#    'player': 'B. Adebayo - MIA',
#    'type': '2-pt layup',
#    'outcome': 'make',
#    'relations': {'AssistedBy': 'G. Dragic - MIA'},
#    'attributes': {'Dist': 1}},
#   {'name': 'TryPt',
#    'player': 'K. Irving - BOS',
#    'type': '2-pt jump shot',
#    'outcome': 'miss',
#    'relations': None,
#    'attributes': {'Dist': 13}},
#   {'name': 'Rebound',
#    'player': 'B. Adebayo - MIA',
#    'type': 'defensive',
#    'outcome': None,
#    'relations': None,
#    'attributes': None},
#   {'name': 'TryPt',
#    'player': 'D. Jones - MIA',
#    'type': '3-pt jump shot',
#    'outcome': 'miss',
#    'relations': None,
#    'attributes': {'Dist': 23}},
#   {'name': 'Rebound',
#    'player': 'B. Adebayo - MIA',
#    'type': 'offensive',
#    'outcome': None,
#    'relations': None,
#    'attributes': None},
#   {'name': 'TryPt',
#    'player': 'B. Adebayo - MIA',
#    'type': '2-pt jump shot',
#    'outcome': 'miss',
#    'relations': None,
#    'attributes': {'Dist': 10}},
#   {'name': 'Rebound',
#    'player': 'K. Irving - BOS',
#    'type': 'defensive',
#    'outcome': None,
#    'relations': None,
#    'attributes': None},
#   {'name': 'TryPt',
#    'player': 'M. Smart - BOS',
#    'type': '3-pt jump shot',
#    'outcome': 'miss',
#    'relations': None,
#    'attributes': {'Dist': 25}},
#   {'name': 'Foul',
#    'player': 'A. Baynes - BOS',
#    'type': 'loose ball',
#    'outcome': None,
#    'relations': {'Fouled': 'D. Jones - MIA'},
#    'attributes': None},
#   {'name': 'TryPt',
#    'player': 'B. Adebayo - MIA',
#    'type': '2-pt jump shot',
#    'outcome': 'miss',
#    'relations': None,
#    'attributes': {'Dist': 18}},
#   {'name': 'Rebound',
#    'player': 'A. Baynes - BOS',
#    'type': 'defensive',
#    'outcome': None,
#    'relations': None,
#    'attributes': None},
#   {'name': 'TryPt',
#    'player': 'M. Smart - BOS',
#    'type': '3-pt jump shot',
#    'outcome': 'make',
#    'relations': {'AssistedBy': 'K. Irving - BOS'},
#    'attributes': {'Dist': 23}},
#   {'name': 'TryPt',
#    'player': 'D. Waiters - MIA',
#    'type': '3-pt jump shot',
#    'outcome': 'miss',
#    'relations': None,
#    'attributes': {'Dist': 25}},
#   {'name': 'Rebound',
#    'player': 'J. Tatum - BOS',
#    'type': 'defensive',
#    'outcome': None,
#    'relations': None,
#    'attributes': None},
#   {'name': 'TryPt',
#    'player': 'J. Tatum - BOS',
#    'type': '2-pt dunk',
#    'outcome': 'make',
#    'relations': {'AssistedBy': 'A. Horford - BOS'},
#    'attributes': {'Dist': 0}},
#   {'name': 'Turnover',
#    'player': 'D. Jones - MIA',
#    'type': 'lost ball',
#    'outcome': None,
#    'relations': {'StolenBy': 'K. Irving - BOS'},
#    'attributes': None},
#   {'name': 'TryPt',
#    'player': 'A. Horford - BOS',
#    'type': '2-pt dunk',
#    'outcome': 'make',
#    'relations': {'AssistedBy': 'J. Tatum - BOS'},
#    'attributes': {'Dist': 1}},
#   {'name': 'TryPt',
#    'player': 'G. Dragic - MIA',
#    'type': '3-pt jump shot',
#    'outcome': 'miss',
#    'relations': None,
#    'attributes': {'Dist': 25}},
#   {'name': 'Rebound',
#    'player': 'K. Irving - BOS',
#    'type': 'defensive',
#    'outcome': None,
#    'relations': None,
#    'attributes': None},
#   {'name': 'Foul',
#    'player': 'D. Waiters - MIA',
#    'type': 'shooting',
#    'outcome': None,
#    'relations': {'Fouled': 'J. Tatum - BOS'},
#    'attributes': None},
#   {'name': 'FreeThrow',
#    'player': 'J. Tatum - BOS',
#    'type': None,
#    'outcome': 'make',
#    'relations': {'Fouler': 'D. Waiters - MIA'},
#    'attributes': None},
#   {'name': 'FreeThrow',
#    'player': 'J. Tatum - BOS',
#    'type': None,
#    'outcome': 'miss',
#    'relations': {'Fouler': 'D. Waiters - MIA'},
#    'attributes': None},
#   {'name': 'Rebound',
#    'player': 'B. Adebayo - MIA',
#    'type': 'defensive',
#    'outcome': None,
#    'relations': None,
#    'attributes': None},
#   {'name': 'Turnover',
#    'player': 'D. Waiters - MIA',
#    'type': 'bad pass',
#    'outcome': None,
#    'relations': {'StolenBy': 'K. Irving - BOS'},
#    'attributes': None},
#   {'name': 'TryPt',
#    'player': 'M. Smart - BOS',
#    'type': '3-pt jump shot',
#    'outcome': 'miss',
#    'relations': None,
#    'attributes': {'Dist': 25}},
#   {'name': 'Rebound',
#    'player': 'J. Tatum - BOS',
#    'type': 'offensive',
#    'outcome': None,
#    'relations': None,
#    'attributes': None},
#   {'name': 'TryPt',
#    'player': 'J. Tatum - BOS',
#    'type': '3-pt jump shot',
#    'outcome': 'make',
#    'relations': None,
#    'attributes': {'Dist': 25}},
#   {'name': 'TryPt',
#    'player': 'D. Waiters - MIA',
#    'type': '3-pt jump shot',
#    'outcome': 'miss',
#    'relations': None,
#    'attributes': {'Dist': 25}},
#   {'name': 'TryPt',
#    'player': 'D. Waiters - MIA',
#    'type': '2-pt jump shot',
#    'outcome': 'miss',
#    'relations': None,
#    'attributes': {'Dist': 11}},
#   {'name': 'Rebound',
#    'player': 'A. Horford - BOS',
#    'type': 'defensive',
#    'outcome': None,
#    'relations': None,
#    'attributes': None},
#   {'name': 'TryPt',
#    'player': 'A. Horford - BOS',
#    'type': '2-pt hook shot',
#    'outcome': 'make',
#    'relations': None,
#    'attributes': {'Dist': 11}},
#   {'name': 'TryPt',
#    'player': 'G. Dragic - MIA',
#    'type': '3-pt jump shot',
#    'outcome': 'miss',
#    'relations': None,
#    'attributes': {'Dist': 23}},
#   {'name': 'Rebound',
#    'player': 'A. Baynes - BOS',
#    'type': 'defensive',
#    'outcome': None,
#    'relations': None,
#    'attributes': None},
#   {'name': 'TryPt',
#    'player': 'K. Irving - BOS',
#    'type': '2-pt jump shot',
#    'outcome': 'miss',
#    'relations': None,
#    'attributes': {'Dist': 19}},
#   {'name': 'Rebound',
#    'player': 'B. Adebayo - MIA',
#    'type': 'defensive',
#    'outcome': None,
#    'relations': None,
#    'attributes': None},
#   {'name': 'TryPt',
#    'player': 'K. Olynyk - MIA',
#    'type': '3-pt jump shot',
#    'outcome': 'miss',
#    'relations': None,
#    'attributes': {'Dist': 25}},
#   {'name': 'Rebound',
#    'player': 'K. Irving - BOS',
#    'type': 'defensive',
#    'outcome': None,
#    'relations': None,
#    'attributes': None},
#   {'name': 'TryPt',
#    'player': 'J. Tatum - BOS',
#    'type': '2-pt jump shot',
#    'outcome': 'make',
#    'relations': None,
#    'attributes': {'Dist': 21}},
#   {'name': 'TryPt',
#    'player': 'B. Adebayo - MIA',
#    'type': '2-pt layup',
#    'outcome': 'make',
#    'relations': {'AssistedBy': 'G. Dragic - MIA'},
#    'attributes': {'Dist': 2}},
#   {'name': 'TryPt',
#    'player': 'K. Irving - BOS',
#    'type': '3-pt jump shot',
#    'outcome': 'make',
#    'relations': {'AssistedBy': 'A. Horford - BOS'},
#    'attributes': {'Dist': 25}},
#   {'name': 'Enter',
#    'player': 'J. Johnson - MIA',
#    'type': None,
#    'outcome': None,
#    'relations': {'Replace': 'B. Adebayo - MIA'},
#    'attributes': None},
#   {'name': 'Enter',
#    'player': 'D. Wade - MIA',
#    'type': None,
#    'outcome': None,
#    'relations': {'Replace': 'K. Olynyk - MIA'},
#    'attributes': None},
#   {'name': 'Enter',
#    'player': 'H. Whiteside - MIA',
#    'type': None,
#    'outcome': None,
#    'relations': {'Replace': 'D. Waiters - MIA'},
#    'attributes': None},
#   {'name': 'Enter',
#    'player': 'G. Hayward - BOS',
#    'type': None,
#    'outcome': None,
#    'relations': {'Replace': 'A. Horford - BOS'},
#    'attributes': None},
#   {'name': 'Enter',
#    'player': 'M. Morris - BOS',
#    'type': None,
#    'outcome': None,
#    'relations': {'Replace': 'M. Smart - BOS'},
#    'attributes': None},
#   {'name': 'TryPt',
#    'player': 'G. Dragic - MIA',
#    'type': '2-pt layup',
#    'outcome': 'miss',
#    'relations': None,
#    'attributes': {'Dist': 3}},
#   {'name': 'Rebound',
#    'player': 'K. Irving - BOS',
#    'type': 'defensive',
#    'outcome': None,
#    'relations': None,
#    'attributes': None},
#   {'name': 'TryPt',
#    'player': 'G. Hayward - BOS',
#    'type': '2-pt dunk',
#    'outcome': 'make',
#    'relations': {'AssistedBy': 'J. Tatum - BOS'},
#    'attributes': {'Dist': 0}},
#   {'name': 'TryPt',
#    'player': 'J. Johnson - MIA',
#    'type': '2-pt layup',
#    'outcome': 'make',
#    'relations': None,
#    'attributes': {'Dist': 5}},
#   {'name': 'Foul',
#    'player': 'M. Morris - BOS',
#    'type': 'shooting',
#    'outcome': None,
#    'relations': {'Fouled': 'J. Johnson - MIA'},
#    'attributes': None},
#   {'name': 'FreeThrow',
#    'player': 'J. Johnson - MIA',
#    'type': None,
#    'outcome': 'miss',
#    'relations': {'Fouler': 'M. Morris - BOS'},
#    'attributes': None},
#   {'name': 'Rebound',
#    'player': 'A. Baynes - BOS',
#    'type': 'defensive',
#    'outcome': None,
#    'relations': None,
#    'attributes': None},
#   {'name': 'TryPt',
#    'player': 'K. Irving - BOS',
#    'type': '3-pt jump shot',
#    'outcome': 'make',
#    'relations': {'AssistedBy': 'M. Morris - BOS'},
#    'attributes': {'Dist': 27}},
#   {'name': 'Foul',
#    'player': 'K. Irving - BOS',
#    'type': 'personal',
#    'outcome': None,
#    'relations': {'Fouled': 'H. Whiteside - MIA'},
#    'attributes': None},
#   {'name': 'TryPt',
#    'player': 'G. Dragic - MIA',
#    'type': '2-pt layup',
#    'outcome': 'make',
#    'relations': {'AssistedBy': 'J. Johnson - MIA'},
#    'attributes': {'Dist': 3}},
#   {'name': 'TryPt',
#    'player': 'M. Morris - BOS',
#    'type': '2-pt jump shot',
#    'outcome': 'miss',
#    'relations': {'BlockedBy': 'D. Jones - MIA'},
#    'attributes': {'Dist': 16}},
#   {'name': 'Rebound',
#    'player': 'H. Whiteside - MIA',
#    'type': 'defensive',
#    'outcome': None,
#    'relations': None,
#    'attributes': None},
#   {'name': 'TryPt',
#    'player': 'H. Whiteside - MIA',
#    'type': '2-pt jump shot',
#    'outcome': 'miss',
#    'relations': None,
#    'attributes': {'Dist': 6}},
#   {'name': 'Rebound',
#    'player': 'A. Baynes - BOS',
#    'type': 'defensive',
#    'outcome': None,
#    'relations': None,
#    'attributes': None},
#   {'name': 'TryPt',
#    'player': 'J. Tatum - BOS',
#    'type': '3-pt jump shot',
#    'outcome': 'make',
#    'relations': {'AssistedBy': 'M. Morris - BOS'},
#    'attributes': {'Dist': 24}},
#   {'name': 'Turnover',
#    'player': 'D. Wade - MIA',
#    'type': 'lost ball',
#    'outcome': None,
#    'relations': {'StolenBy': 'G. Hayward - BOS'},
#    'attributes': None},
#   {'name': 'Foul',
#    'player': 'G. Dragic - MIA',
#    'type': 'shooting',
#    'outcome': None,
#    'relations': {'Fouled': 'G. Hayward - BOS'},
#    'attributes': None},
#   {'name': 'FreeThrow',
#    'player': 'G. Hayward - BOS',
#    'type': None,
#    'outcome': 'make',
#    'relations': {'Fouler': 'G. Dragic - MIA'},
#    'attributes': None},
#   {'name': 'Enter',
#    'player': 'R. Anderson - MIA',
#    'type': None,
#    'outcome': None,
#    'relations': {'Replace': 'D. Jones - MIA'},
#    'attributes': None},
#   {'name': 'FreeThrow',
#    'player': 'G. Hayward - BOS',
#    'type': None,
#    'outcome': 'make',
#    'relations': {'Fouler': 'G. Dragic - MIA'},
#    'attributes': None},
#   {'name': 'Foul',
#    'player': 'A. Baynes - BOS',
#    'type': 'shooting',
#    'outcome': None,
#    'relations': {'Fouled': 'J. Johnson - MIA'},
#    'attributes': None},
#   {'name': 'FreeThrow',
#    'player': 'J. Johnson - MIA',
#    'type': None,
#    'outcome': 'make',
#    'relations': {'Fouler': 'A. Baynes - BOS'},
#    'attributes': None},
#   {'name': 'FreeThrow',
#    'player': 'J. Johnson - MIA',
#    'type': None,
#    'outcome': 'make',
#    'relations': {'Fouler': 'A. Baynes - BOS'},
#    'attributes': None},
#   {'name': 'Foul',
#    'player': 'H. Whiteside - MIA',
#    'type': 'shooting',
#    'outcome': None,
#    'relations': {'Fouled': 'A. Baynes - BOS'},
#    'attributes': None},
#   {'name': 'FreeThrow',
#    'player': 'A. Baynes - BOS',
#    'type': None,
#    'outcome': 'make',
#    'relations': {'Fouler': 'H. Whiteside - MIA'},
#    'attributes': None},
#   {'name': 'Enter',
#    'player': 'T. Rozier - BOS',
#    'type': None,
#    'outcome': None,
#    'relations': {'Replace': 'K. Irving - BOS'},
#    'attributes': None},
#   {'name': 'FreeThrow',
#    'player': 'A. Baynes - BOS',
#    'type': None,
#    'outcome': 'make',
#    'relations': {'Fouler': 'H. Whiteside - MIA'},
#    'attributes': None},
#   {'name': 'TryPt',
#    'player': 'D. Wade - MIA',
#    'type': '2-pt jump shot',
#    'outcome': 'make',
#    'relations': {'AssistedBy': 'J. Johnson - MIA'},
#    'attributes': {'Dist': 17}},
#   {'name': 'Turnover',
#    'player': 'G. Hayward - BOS',
#    'type': 'bad pass',
#    'outcome': None,
#    'relations': {'StolenBy': 'D. Wade - MIA'},
#    'attributes': None},
#   {'name': 'TryPt',
#    'player': 'G. Dragic - MIA',
#    'type': '2-pt layup',
#    'outcome': 'make',
#    'relations': {'AssistedBy': 'H. Whiteside - MIA'},
#    'attributes': {'Dist': 1}},
#   {'name': 'TryPt',
#    'player': 'J. Tatum - BOS',
#    'type': '2-pt layup',
#    'outcome': 'miss',
#    'relations': None,
#    'attributes': {'Dist': 4}},
#   {'name': 'Rebound',
#    'player': 'R. Anderson - MIA',
#    'type': 'defensive',
#    'outcome': None,
#    'relations': None,
#    'attributes': None},
#   {'name': 'TryPt',
#    'player': 'H. Whiteside - MIA',
#    'type': '2-pt layup',
#    'outcome': 'make',
#    'relations': {'AssistedBy': 'J. Johnson - MIA'},
#    'attributes': {'Dist': 4}},
#   {'name': 'Foul',
#    'player': 'H. Whiteside - MIA',
#    'type': 'shooting',
#    'outcome': None,
#    'relations': {'Fouled': 'A. Baynes - BOS'},
#    'attributes': None},
#   {'name': 'FreeThrow',
#    'player': 'A. Baynes - BOS',
#    'type': None,
#    'outcome': 'make',
#    'relations': {'Fouler': 'H. Whiteside - MIA'},
#    'attributes': None},
#   {'name': 'Enter',
#    'player': 'D. Waiters - MIA',
#    'type': None,
#    'outcome': None,
#    'relations': {'Replace': 'G. Dragic - MIA'},
#    'attributes': None},
#   {'name': 'FreeThrow',
#    'player': 'A. Baynes - BOS',
#    'type': None,
#    'outcome': 'make',
#    'relations': {'Fouler': 'H. Whiteside - MIA'},
#    'attributes': None},
#   {'name': 'TryPt',
#    'player': 'H. Whiteside - MIA',
#    'type': '2-pt layup',
#    'outcome': 'miss',
#    'relations': None,
#    'attributes': {'Dist': 1}},
#   {'name': 'Rebound',
#    'player': 'H. Whiteside - MIA',
#    'type': 'offensive',
#    'outcome': None,
#    'relations': None,
#    'attributes': None},
#   {'name': 'Foul',
#    'player': 'A. Baynes - BOS',
#    'type': 'shooting',
#    'outcome': None,
#    'relations': {'Fouled': 'H. Whiteside - MIA'},
#    'attributes': None},
#   {'name': 'FreeThrow',
#    'player': 'H. Whiteside - MIA',
#    'type': None,
#    'outcome': 'make',
#    'relations': {'Fouler': 'A. Baynes - BOS'},
#    'attributes': None},
#   {'name': 'Enter',
#    'player': 'A. Horford - BOS',
#    'type': None,
#    'outcome': None,
#    'relations': {'Replace': 'A. Baynes - BOS'},
#    'attributes': None},
#   {'name': 'FreeThrow',
#    'player': 'H. Whiteside - MIA',
#    'type': None,
#    'outcome': 'miss',
#    'relations': {'Fouler': 'A. Baynes - BOS'},
#    'attributes': None},
#   {'name': 'Rebound',
#    'player': 'T. Rozier - BOS',
#    'type': 'defensive',
#    'outcome': None,
#    'relations': None,
#    'attributes': None},
#   {'name': 'Foul',
#    'player': 'D. Waiters - MIA',
#    'type': 'personal',
#    'outcome': None,
#    'relations': {'Fouled': 'T. Rozier - BOS'},
#    'attributes': None},
#   {'name': 'FreeThrow',
#    'player': 'T. Rozier - BOS',
#    'type': None,
#    'outcome': 'make',
#    'relations': {'Fouler': 'D. Waiters - MIA'},
#    'attributes': None},
#   {'name': 'FreeThrow',
#    'player': 'T. Rozier - BOS',
#    'type': None,
#    'outcome': 'make',
#    'relations': {'Fouler': 'D. Waiters - MIA'},
#    'attributes': None},
#   {'name': 'TryPt',
#    'player': 'D. Wade - MIA',
#    'type': '2-pt jump shot',
#    'outcome': 'miss',
#    'relations': None,
#    'attributes': {'Dist': 6}},
#   {'name': 'Rebound',
#    'player': 'M. Morris - BOS',
#    'type': 'defensive',
#    'outcome': None,
#    'relations': None,
#    'attributes': None},
#   {'name': 'TryPt',
#    'player': 'M. Morris - BOS',
#    'type': '3-pt jump shot',
#    'outcome': 'miss',
#    'relations': None,
#    'attributes': {'Dist': 26}},
#   {'name': 'Rebound',
#    'player': 'R. Anderson - MIA',
#    'type': 'defensive',
#    'outcome': None,
#    'relations': None,
#    'attributes': None},
#   {'name': 'TryPt',
#    'player': 'D. Waiters - MIA',
#    'type': '2-pt layup',
#    'outcome': 'miss',
#    'relations': None,
#    'attributes': {'Dist': 3}},
#   {'name': 'Rebound',
#    'player': 'G. Hayward - BOS',
#    'type': 'defensive',
#    'outcome': None,
#    'relations': None,
#    'attributes': None},
#   {'name': 'TryPt',
#    'player': 'M. Morris - BOS',
#    'type': '3-pt jump shot',
#    'outcome': 'miss',
#    'relations': None,
#    'attributes': {'Dist': 24}},
#   {'name': 'Rebound',
#    'player': 'R. Anderson - MIA',
#    'type': 'defensive',
#    'outcome': None,
#    'relations': None,
#    'attributes': None},
#   {'name': 'TryPt',
#    'player': 'R. Anderson - MIA',
#    'type': '3-pt jump shot',
#    'outcome': 'miss',
#    'relations': None,
#    'attributes': {'Dist': 69}},
#   {'name': 'TryPt',
#    'player': 'D. Waiters - MIA',
#    'type': '2-pt layup',
#    'outcome': 'make',
#    'relations': None,
#    'attributes': {'Dist': 4}},
#   {'name': 'TryPt',
#    'player': 'G. Hayward - BOS',
#    'type': '3-pt jump shot',
#    'outcome': 'miss',
#    'relations': None,
#    'attributes': {'Dist': 24}},
#   {'name': 'Rebound',
#    'player': 'A. Horford - BOS',
#    'type': 'offensive',
#    'outcome': None,
#    'relations': None,
#    'attributes': None},
#   {'name': 'Turnover',
#    'player': 'A. Horford - BOS',
#    'type': 'bad pass',
#    'outcome': None,
#    'relations': None,
#    'attributes': None},
#   {'name': 'TryPt',
#    'player': 'D. Waiters - MIA',
#    'type': '3-pt jump shot',
#    'outcome': 'miss',
#    'relations': None,
#    'attributes': {'Dist': 27}},
#   {'name': 'Rebound',
#    'player': 'R. Anderson - MIA',
#    'type': 'offensive',
#    'outcome': None,
#    'relations': None,
#    'attributes': None},
#   {'name': 'TryPt',
#    'player': 'G. Dragic - MIA',
#    'type': '3-pt jump shot',
#    'outcome': 'miss',
#    'relations': None,
#    'attributes': {'Dist': 25}},
#   {'name': 'Rebound',
#    'player': 'A. Horford - BOS',
#    'type': 'defensive',
#    'outcome': None,
#    'relations': None,
#    'attributes': None},
#   {'name': 'TryPt',
#    'player': 'A. Horford - BOS',
#    'type': '2-pt dunk',
#    'outcome': 'make',
#    'relations': None,
#    'attributes': {'Dist': 1}},
#   {'name': 'Foul',
#    'player': 'J. Johnson - MIA',
#    'type': 'shooting',
#    'outcome': None,
#    'relations': {'Fouled': 'A. Horford - BOS'},
#    'attributes': None},
#   {'name': 'FreeThrow',
#    'player': 'A. Horford - BOS',
#    'type': None,
#    'outcome': 'make',
#    'relations': {'Fouler': 'J. Johnson - MIA'},
#    'attributes': None},
#   {'name': 'TryPt',
#    'player': 'J. Johnson - MIA',
#    'type': '2-pt layup',
#    'outcome': 'miss',
#    'relations': None,
#    'attributes': {'Dist': 2}},
#   {'name': 'Foul',
#    'player': 'M. Morris - BOS',
#    'type': 'loose ball',
#    'outcome': None,
#    'relations': {'Fouled': 'H. Whiteside - MIA'},
#    'attributes': None},
#   {'name': 'Enter',
#    'player': 'B. Adebayo - MIA',
#    'type': None,
#    'outcome': None,
#    'relations': {'Replace': 'G. Dragic - MIA'},
#    'attributes': None},
#   {'name': 'Enter',
#    'player': 'D. Wade - MIA',
#    'type': None,
#    'outcome': None,
#    'relations': {'Replace': 'H. Whiteside - MIA'},
#    'attributes': None},
#   {'name': 'TryPt',
#    'player': 'D. Wade - MIA',
#    'type': '2-pt jump shot',
#    'outcome': 'miss',
#    'relations': None,
#    'attributes': {'Dist': 16}},
#   {'name': 'Rebound',
#    'player': 'A. Horford - BOS',
#    'type': 'defensive',
#    'outcome': None,
#    'relations': None,
#    'attributes': None},
#   {'name': 'TryPt',
#    'player': 'A. Horford - BOS',
#    'type': '2-pt hook shot',
#    'outcome': 'miss',
#    'relations': None,
#    'attributes': {'Dist': 8}},
#   {'name': 'Rebound',
#    'player': 'D. Wade - MIA',
#    'type': 'defensive',
#    'outcome': None,
#    'relations': None,
#    'attributes': None},
#   {'name': 'Turnover',
#    'player': 'J. Johnson - MIA',
#    'type': 'bad pass',
#    'outcome': None,
#    'relations': {'StolenBy': 'M. Morris - BOS'},
#    'attributes': None},
#   {'name': 'TryPt',
#    'player': 'T. Rozier - BOS',
#    'type': '2-pt layup',
#    'outcome': 'miss',
#    'relations': None,
#    'attributes': {'Dist': 3}},
#   {'name': 'Rebound',
#    'player': 'J. Johnson - MIA',
#    'type': 'defensive',
#    'outcome': None,
#    'relations': None,
#    'attributes': None},
#   {'name': 'TryPt',
#    'player': 'D. Waiters - MIA',
#    'type': '2-pt hook shot',
#    'outcome': 'make',
#    'relations': None,
#    'attributes': {'Dist': 2}},
#   {'name': 'TryPt',
#    'player': 'S. Ojeleye - BOS',
#    'type': '2-pt layup',
#    'outcome': 'make',
#    'relations': {'AssistedBy': 'A. Horford - BOS'},
#    'attributes': {'Dist': 1}},
#   {'name': 'Foul',
#    'player': 'B. Adebayo - MIA',
#    'type': 'shooting',
#    'outcome': None,
#    'relations': {'Fouled': 'S. Ojeleye - BOS'},
#    'attributes': None},
#   {'name': 'Enter',
#    'player': 'D. Jones - MIA',
#    'type': None,
#    'outcome': None,
#    'relations': {'Replace': 'R. Anderson - MIA'},
#    'attributes': None},
#   {'name': 'Enter',
#    'player': 'K. Olynyk - MIA',
#    'type': None,
#    'outcome': None,
#    'relations': {'Replace': 'J. Johnson - MIA'},
#    'attributes': None},
#   {'name': 'FreeThrow',
#    'player': 'S. Ojeleye - BOS',
#    'type': None,
#    'outcome': 'miss',
#    'relations': {'Fouler': 'B. Adebayo - MIA'},
#    'attributes': None},
#   {'name': 'Rebound',
#    'player': 'B. Adebayo - MIA',
#    'type': 'defensive',
#    'outcome': None,
#    'relations': None,
#    'attributes': None},
#   {'name': 'TryPt',
#    'player': 'B. Adebayo - MIA',
#    'type': '2-pt layup',
#    'outcome': 'make',
#    'relations': {'AssistedBy': 'D. Wade - MIA'},
#    'attributes': {'Dist': 2}},
#   {'name': 'TryPt',
#    'player': 'M. Morris - BOS',
#    'type': '3-pt jump shot',
#    'outcome': 'make',
#    'relations': {'AssistedBy': 'A. Horford - BOS'},
#    'attributes': {'Dist': 25}},
#   {'name': 'TryPt',
#    'player': 'D. Waiters - MIA',
#    'type': '2-pt jump shot',
#    'outcome': 'miss',
#    'relations': None,
#    'attributes': {'Dist': 4}},
#   {'name': 'Rebound',
#    'player': 'A. Horford - BOS',
#    'type': 'defensive',
#    'outcome': None,
#    'relations': None,
#    'attributes': None},
#   {'name': 'TryPt',
#    'player': 'G. Hayward - BOS',
#    'type': '2-pt layup',
#    'outcome': 'make',
#    'relations': {'AssistedBy': 'A. Horford - BOS'},
#    'attributes': {'Dist': 1}},
#   {'name': 'TryPt',
#    'player': 'B. Adebayo - MIA',
#    'type': '2-pt dunk',
#    'outcome': 'make',
#    'relations': {'AssistedBy': 'D. Wade - MIA'},
#    'attributes': {'Dist': 2}},
#   {'name': 'TryPt',
#    'player': 'A. Horford - BOS',
#    'type': '2-pt hook shot',
#    'outcome': 'miss',
#    'relations': None,
#    'attributes': {'Dist': 6}},
#   {'name': 'Rebound',
#    'player': 'B. Adebayo - MIA',
#    'type': 'defensive',
#    'outcome': None,
#    'relations': None,
#    'attributes': None},
#   {'name': 'Foul',
#    'player': 'G. Hayward - BOS',
#    'type': 'personal',
#    'outcome': None,
#    'relations': {'Fouled': 'B. Adebayo - MIA'},
#    'attributes': None},
#   {'name': 'Enter',
#    'player': 'A. Baynes - BOS',
#    'type': None,
#    'outcome': None,
#    'relations': {'Replace': 'G. Hayward - BOS'},
#    'attributes': None},
#   {'name': 'Enter',
#    'player': 'K. Irving - BOS',
#    'type': None,
#    'outcome': None,
#    'relations': {'Replace': 'A. Horford - BOS'},
#    'attributes': None},
#   {'name': 'Enter',
#    'player': 'M. Smart - BOS',
#    'type': None,
#    'outcome': None,
#    'relations': {'Replace': 'M. Morris - BOS'},
#    'attributes': None},
#   {'name': 'TryPt',
#    'player': 'D. Wade - MIA',
#    'type': '2-pt jump shot',
#    'outcome': 'make',
#    'relations': None,
#    'attributes': {'Dist': 12}},
#   {'name': 'Foul',
#    'player': 'A. Baynes - BOS',
#    'type': 'shooting',
#    'outcome': None,
#    'relations': {'Fouled': 'D. Wade - MIA'},
#    'attributes': None},
#   {'name': 'FreeThrow',
#    'player': 'D. Wade - MIA',
#    'type': None,
#    'outcome': 'make',
#    'relations': {'Fouler': 'A. Baynes - BOS'},
#    'attributes': None},
#   {'name': 'TryPt',
#    'player': 'K. Irving - BOS',
#    'type': '2-pt jump shot',
#    'outcome': 'miss',
#    'relations': None,
#    'attributes': {'Dist': 11}},
#   {'name': 'Rebound',
#    'player': 'B. Adebayo - MIA',
#    'type': 'defensive',
#    'outcome': None,
#    'relations': None,
#    'attributes': None},
#   {'name': 'TryPt',
#    'player': 'D. Wade - MIA',
#    'type': '2-pt jump shot',
#    'outcome': 'make',
#    'relations': None,
#    'attributes': {'Dist': 7}},
#   {'name': 'Enter',
#    'player': 'D. Theis - BOS',
#    'type': None,
#    'outcome': None,
#    'relations': {'Replace': 'A. Baynes - BOS'},
#    'attributes': None},
#   {'name': 'TryPt',
#    'player': 'T. Rozier - BOS',
#    'type': '3-pt jump shot',
#    'outcome': 'miss',
#    'relations': None,
#    'attributes': {'Dist': 26}},
#   {'name': 'Rebound',
#    'player': 'B. Adebayo - MIA',
#    'type': 'defensive',
#    'outcome': None,
#    'relations': None,
#    'attributes': None},
#   {'name': 'Enter',
#    'player': 'J. Tatum - BOS',
#    'type': None,
#    'outcome': None,
#    'relations': {'Replace': 'S. Ojeleye - BOS'},
#    'attributes': None},
#   {'name': 'Enter',
#    'player': 'G. Yabusele - BOS',
#    'type': None,
#    'outcome': None,
#    'relations': {'Replace': 'T. Rozier - BOS'},
#    'attributes': None},
#   {'name': 'TryPt',
#    'player': 'K. Olynyk - MIA',
#    'type': '3-pt jump shot',
#    'outcome': 'make',
#    'relations': {'AssistedBy': 'D. Wade - MIA'},
#    'attributes': {'Dist': 23}},
#   {'name': 'TryPt',
#    'player': 'D. Theis - BOS',
#    'type': '2-pt jump shot',
#    'outcome': 'miss',
#    'relations': None,
#    'attributes': {'Dist': 14}},
#   {'name': 'Rebound',
#    'player': 'G. Yabusele - BOS',
#    'type': 'offensive',
#    'outcome': None,
#    'relations': None,
#    'attributes': None},
#   {'name': 'TryPt',
#    'player': 'K. Irving - BOS',
#    'type': '3-pt jump shot',
#    'outcome': 'make',
#    'relations': {'AssistedBy': 'G. Yabusele - BOS'},
#    'attributes': {'Dist': 27}},
#   {'name': 'TryPt',
#    'player': 'D. Wade - MIA',
#    'type': '2-pt jump shot',
#    'outcome': 'miss',
#    'relations': None,
#    'attributes': {'Dist': 12}},
#   {'name': 'Rebound',
#    'player': 'J. Tatum - BOS',
#    'type': 'defensive',
#    'outcome': None,
#    'relations': None,
#    'attributes': None},
#   {'name': 'TryPt',
#    'player': 'K. Irving - BOS',
#    'type': '3-pt jump shot',
#    'outcome': 'make',
#    'relations': {'AssistedBy': 'J. Tatum - BOS'},
#    'attributes': {'Dist': 25}},
#   {'name': 'Enter',
#    'player': 'G. Dragic - MIA',
#    'type': None,
#    'outcome': None,
#    'relations': {'Replace': 'D. Wade - MIA'},
#    'attributes': None},
#   {'name': 'TryPt',
#    'player': 'D. Waiters - MIA',
#    'type': '3-pt jump shot',
#    'outcome': 'miss',
#    'relations': None,
#    'attributes': {'Dist': 27}},
#   {'name': 'Rebound',
#    'player': 'B. Adebayo - MIA',
#    'type': 'offensive',
#    'outcome': None,
#    'relations': None,
#    'attributes': None},
#   {'name': 'Turnover',
#    'player': 'D. Waiters - MIA',
#    'type': 'bad pass',
#    'outcome': None,
#    'relations': None,
#    'attributes': None},
#   {'name': 'Foul',
#    'player': 'D. Waiters - MIA',
#    'type': 'technical',
#    'outcome': None,
#    'relations': {'Fouled': ''},
#    'attributes': None},
#   {'name': 'FreeThrow',
#    'player': 'K. Irving - BOS',
#    'type': None,
#    'outcome': 'make',
#    'relations': {'Fouler': 'D. Waiters - MIA'},
#    'attributes': None},
#   {'name': 'TryPt',
#    'player': 'D. Theis - BOS',
#    'type': '2-pt layup',
#    'outcome': 'miss',
#    'relations': {'BlockedBy': 'B. Adebayo - MIA'},
#    'attributes': {'Dist': 5}},
#   {'name': 'Rebound',
#    'player': 'B. Adebayo - MIA',
#    'type': 'defensive',
#    'outcome': None,
#    'relations': None,
#    'attributes': None},
#   {'name': 'TryPt',
#    'player': 'B. Adebayo - MIA',
#    'type': '2-pt jump shot',
#    'outcome': 'miss',
#    'relations': None,
#    'attributes': {'Dist': 13}},
#   {'name': 'Rebound',
#    'player': 'J. Tatum - BOS',
#    'type': 'defensive',
#    'outcome': None,
#    'relations': None,
#    'attributes': None},
#   {'name': 'TryPt',
#    'player': 'J. Tatum - BOS',
#    'type': '2-pt jump shot',
#    'outcome': 'miss',
#    'relations': {'BlockedBy': 'B. Adebayo - MIA'},
#    'attributes': {'Dist': 18}},
#   {'name': 'TryPt',
#    'player': 'J. Tatum - BOS',
#    'type': '3-pt jump shot',
#    'outcome': 'miss',
#    'relations': None,
#    'attributes': {'Dist': 28}},
#   {'name': 'Rebound',
#    'player': 'D. Waiters - MIA',
#    'type': 'defensive',
#    'outcome': None,
#    'relations': None,
#    'attributes': None},
#   {'name': 'Enter',
#    'player': 'A. Horford - BOS',
#    'type': None,
#    'outcome': None,
#    'relations': {'Replace': 'G. Yabusele - BOS'},
#    'attributes': None},
#   {'name': 'TryPt',
#    'player': 'B. Adebayo - MIA',
#    'type': '2-pt layup',
#    'outcome': 'miss',
#    'relations': None,
#    'attributes': {'Dist': 4}},
#   {'name': 'Rebound',
#    'player': 'D. Theis - BOS',
#    'type': 'defensive',
#    'outcome': None,
#    'relations': None,
#    'attributes': None},
#   {'name': 'Foul',
#    'player': 'B. Adebayo - MIA',
#    'type': 'shooting',
#    'outcome': None,
#    'relations': {'Fouled': 'D. Theis - BOS'},
#    'attributes': None},
#   {'name': 'FreeThrow',
#    'player': 'D. Theis - BOS',
#    'type': None,
#    'outcome': 'miss',
#    'relations': {'Fouler': 'B. Adebayo - MIA'},
#    'attributes': None},
#   {'name': 'Enter',
#    'player': 'G. Hayward - BOS',
#    'type': None,
#    'outcome': None,
#    'relations': {'Replace': 'J. Tatum - BOS'},
#    'attributes': None},
#   {'name': 'FreeThrow',
#    'player': 'D. Theis - BOS',
#    'type': None,
#    'outcome': 'make',
#    'relations': {'Fouler': 'B. Adebayo - MIA'},
#    'attributes': None},
#   {'name': 'Foul',
#    'player': 'A. Horford - BOS',
#    'type': 'shooting',
#    'outcome': None,
#    'relations': {'Fouled': 'D. Jones - MIA'},
#    'attributes': None},
#   {'name': 'FreeThrow',
#    'player': 'D. Jones - MIA',
#    'type': None,
#    'outcome': 'miss',
#    'relations': {'Fouler': 'A. Horford - BOS'},
#    'attributes': None},
#   {'name': 'FreeThrow',
#    'player': 'D. Jones - MIA',
#    'type': None,
#    'outcome': 'make',
#    'relations': {'Fouler': 'A. Horford - BOS'},
#    'attributes': None},
#   {'name': 'TryPt',
#    'player': 'K. Irving - BOS',
#    'type': '3-pt jump shot',
#    'outcome': 'miss',
#    'relations': None,
#    'attributes': {'Dist': 26}},
#   {'name': 'Rebound',
#    'player': 'K. Olynyk - MIA',
#    'type': 'defensive',
#    'outcome': None,
#    'relations': None,
#    'attributes': None},
#   {'name': 'Foul',
#    'player': 'M. Smart - BOS',
#    'type': 'shooting',
#    'outcome': None,
#    'relations': {'Fouled': 'G. Dragic - MIA'},
#    'attributes': None},
#   {'name': 'FreeThrow',
#    'player': 'G. Dragic - MIA',
#    'type': None,
#    'outcome': 'make',
#    'relations': {'Fouler': 'M. Smart - BOS'},
#    'attributes': None},
#   {'name': 'FreeThrow',
#    'player': 'G. Dragic - MIA',
#    'type': None,
#    'outcome': 'make',
#    'relations': {'Fouler': 'M. Smart - BOS'},
#    'attributes': None},
#   {'name': 'TryPt',
#    'player': 'M. Smart - BOS',
#    'type': '3-pt jump shot',
#    'outcome': 'make',
#    'relations': {'AssistedBy': 'A. Horford - BOS'},
#    'attributes': {'Dist': 26}},
#   {'name': 'TryPt',
#    'player': 'G. Dragic - MIA',
#    'type': '2-pt layup',
#    'outcome': 'make',
#    'relations': {'AssistedBy': 'B. Adebayo - MIA'},
#    'attributes': {'Dist': 1}},
#   {'name': 'TryPt',
#    'player': 'K. Irving - BOS',
#    'type': '2-pt jump shot',
#    'outcome': 'miss',
#    'relations': None,
#    'attributes': {'Dist': 8}},
#   {'name': 'Rebound',
#    'player': 'A. Horford - BOS',
#    'type': 'offensive',
#    'outcome': None,
#    'relations': None,
#    'attributes': None},
#   {'name': 'TryPt',
#    'player': 'A. Horford - BOS',
#    'type': '2-pt layup',
#    'outcome': 'make',
#    'relations': None,
#    'attributes': {'Dist': 1}},
#   {'name': 'Foul',
#    'player': 'D. Theis - BOS',
#    'type': 'shooting',
#    'outcome': None,
#    'relations': {'Fouled': 'B. Adebayo - MIA'},
#    'attributes': None},
#   {'name': 'FreeThrow',
#    'player': 'B. Adebayo - MIA',
#    'type': None,
#    'outcome': 'make',
#    'relations': {'Fouler': 'D. Theis - BOS'},
#    'attributes': None},
#   {'name': 'Enter',
#    'player': 'D. Wade - MIA',
#    'type': None,
#    'outcome': None,
#    'relations': {'Replace': 'D. Waiters - MIA'},
#    'attributes': None},
#   {'name': 'Enter',
#    'player': 'M. Morris - BOS',
#    'type': None,
#    'outcome': None,
#    'relations': {'Replace': 'D. Theis - BOS'},
#    'attributes': None},
#   {'name': 'FreeThrow',
#    'player': 'B. Adebayo - MIA',
#    'type': None,
#    'outcome': 'make',
#    'relations': {'Fouler': 'D. Theis - BOS'},
#    'attributes': None},
#   {'name': 'Turnover',
#    'player': 'K. Irving - BOS',
#    'type': 'bad pass',
#    'outcome': None,
#    'relations': {'StolenBy': 'G. Dragic - MIA'},
#    'attributes': None},
#   {'name': 'TryPt',
#    'player': 'G. Dragic - MIA',
#    'type': '2-pt layup',
#    'outcome': 'make',
#    'relations': None,
#    'attributes': {'Dist': 1}},
#   {'name': 'TryPt',
#    'player': 'M. Smart - BOS',
#    'type': '3-pt jump shot',
#    'outcome': 'miss',
#    'relations': None,
#    'attributes': {'Dist': 29}},
#   {'name': 'Rebound',
#    'player': 'K. Olynyk - MIA',
#    'type': 'defensive',
#    'outcome': None,
#    'relations': None,
#    'attributes': None},
#   {'name': 'TryPt',
#    'player': 'D. Wade - MIA',
#    'type': '2-pt jump shot',
#    'outcome': 'make',
#    'relations': None,
#    'attributes': {'Dist': 4}},
#   {'name': 'TryPt',
#    'player': 'K. Irving - BOS',
#    'type': '3-pt jump shot',
#    'outcome': 'miss',
#    'relations': None,
#    'attributes': {'Dist': 24}},
#   {'name': 'Rebound',
#    'player': 'D. Jones - MIA',
#    'type': 'defensive',
#    'outcome': None,
#    'relations': None,
#    'attributes': None},
#   {'name': 'Turnover',
#    'player': 'D. Wade - MIA',
#    'type': 'lost ball',
#    'outcome': None,
#    'relations': {'StolenBy': 'G. Hayward - BOS'},
#    'attributes': None},
#   {'name': 'Foul',
#    'player': 'D. Jones - MIA',
#    'type': 'shooting',
#    'outcome': None,
#    'relations': {'Fouled': 'K. Irving - BOS'},
#    'attributes': None},
#   {'name': 'FreeThrow',
#    'player': 'K. Irving - BOS',
#    'type': None,
#    'outcome': 'make',
#    'relations': {'Fouler': 'D. Jones - MIA'},
#    'attributes': None},
#   {'name': 'Enter',
#    'player': 'D. Waiters - MIA',
#    'type': None,
#    'outcome': None,
#    'relations': {'Replace': 'B. Adebayo - MIA'},
#    'attributes': None},
#   {'name': 'Enter',
#    'player': 'H. Whiteside - MIA',
#    'type': None,
#    'outcome': None,
#    'relations': {'Replace': 'D. Jones - MIA'},
#    'attributes': None},
#   {'name': 'FreeThrow',
#    'player': 'K. Irving - BOS',
#    'type': None,
#    'outcome': 'make',
#    'relations': {'Fouler': 'D. Jones - MIA'},
#    'attributes': None},
#   {'name': 'TryPt',
#    'player': 'D. Waiters - MIA',
#    'type': '3-pt jump shot',
#    'outcome': 'make',
#    'relations': {'AssistedBy': 'D. Wade - MIA'},
#    'attributes': {'Dist': 23}},
#   {'name': 'TryPt',
#    'player': 'K. Irving - BOS',
#    'type': '2-pt layup',
#    'outcome': 'miss',
#    'relations': None,
#    'attributes': {'Dist': 4}},
#   {'name': 'Rebound',
#    'player': 'H. Whiteside - MIA',
#    'type': 'defensive',
#    'outcome': None,
#    'relations': None,
#    'attributes': None},
#   {'name': 'TryPt',
#    'player': 'G. Dragic - MIA',
#    'type': '3-pt jump shot',
#    'outcome': 'make',
#    'relations': {'AssistedBy': 'D. Waiters - MIA'},
#    'attributes': {'Dist': 25}},
#   {'name': 'TryPt',
#    'player': 'M. Smart - BOS',
#    'type': '3-pt jump shot',
#    'outcome': 'make',
#    'relations': {'AssistedBy': 'A. Horford - BOS'},
#    'attributes': {'Dist': 23}},
#   {'name': 'Turnover',
#    'player': 'G. Dragic - MIA',
#    'type': 'out of bounds lost ball',
#    'outcome': None,
#    'relations': None,
#    'attributes': None},
#   {'name': 'TryPt',
#    'player': 'A. Horford - BOS',
#    'type': '2-pt jump shot',
#    'outcome': 'miss',
#    'relations': None,
#    'attributes': {'Dist': 17}},
#   {'name': 'Rebound',
#    'player': 'D. Waiters - MIA',
#    'type': 'defensive',
#    'outcome': None,
#    'relations': None,
#    'attributes': None},
#   {'name': 'TryPt',
#    'player': 'G. Dragic - MIA',
#    'type': '2-pt layup',
#    'outcome': 'miss',
#    'relations': None,
#    'attributes': {'Dist': 2}},
#   {'name': 'TryPt',
#    'player': 'K. Irving - BOS',
#    'type': '2-pt jump shot',
#    'outcome': 'make',
#    'relations': {'AssistedBy': 'A. Horford - BOS'},
#    'attributes': {'Dist': 15}},
#   {'name': 'TryPt',
#    'player': 'J. Johnson - MIA',
#    'type': '3-pt jump shot',
#    'outcome': 'miss',
#    'relations': None,
#    'attributes': {'Dist': 26}},
#   {'name': 'Rebound',
#    'player': 'A. Baynes - BOS',
#    'type': 'defensive',
#    'outcome': None,
#    'relations': None,
#    'attributes': None},
#   {'name': 'TryPt',
#    'player': 'J. Tatum - BOS',
#    'type': '3-pt jump shot',
#    'outcome': 'miss',
#    'relations': None,
#    'attributes': {'Dist': 27}},
#   {'name': 'Rebound',
#    'player': 'G. Dragic - MIA',
#    'type': 'defensive',
#    'outcome': None,
#    'relations': None,
#    'attributes': None},
#   {'name': 'TryPt',
#    'player': 'K. Olynyk - MIA',
#    'type': '3-pt jump shot',
#    'outcome': 'make',
#    'relations': {'AssistedBy': 'B. Adebayo - MIA'},
#    'attributes': {'Dist': 26}},
#   {'name': 'Turnover',
#    'player': 'K. Irving - BOS',
#    'type': 'bad pass',
#    'outcome': None,
#    'relations': {'StolenBy': 'K. Olynyk - MIA'},
#    'attributes': None},
#   {'name': 'TryPt',
#    'player': 'G. Dragic - MIA',
#    'type': '2-pt layup',
#    'outcome': 'make',
#    'relations': None,
#    'attributes': {'Dist': 0}},
#   {'name': 'TryPt',
#    'player': 'A. Baynes - BOS',
#    'type': '2-pt hook shot',
#    'outcome': 'miss',
#    'relations': None,
#    'attributes': {'Dist': 7}},
#   {'name': 'Rebound',
#    'player': 'B. Adebayo - MIA',
#    'type': 'defensive',
#    'outcome': None,
#    'relations': None,
#    'attributes': None},
#   {'name': 'TryPt',
#    'player': 'J. Johnson - MIA',
#    'type': '2-pt layup',
#    'outcome': 'miss',
#    'relations': None,
#    'attributes': {'Dist': 2}},
#   {'name': 'Rebound',
#    'player': 'A. Baynes - BOS',
#    'type': 'defensive',
#    'outcome': None,
#    'relations': None,
#    'attributes': None},
#   {'name': 'Turnover',
#    'player': 'M. Smart - BOS',
#    'type': 'lost ball',
#    'outcome': None,
#    'relations': {'StolenBy': 'G. Dragic - MIA'},
#    'attributes': None},
#   {'name': 'TryPt',
#    'player': 'G. Dragic - MIA',
#    'type': '2-pt layup',
#    'outcome': 'make',
#    'relations': None,
#    'attributes': {'Dist': 1}},
#   {'name': 'Foul',
#    'player': 'K. Irving - BOS',
#    'type': 'shooting',
#    'outcome': None,
#    'relations': {'Fouled': 'G. Dragic - MIA'},
#    'attributes': None},
#   {'name': 'Enter',
#    'player': 'D. Theis - BOS',
#    'type': None,
#    'outcome': None,
#    'relations': {'Replace': 'A. Baynes - BOS'},
#    'attributes': None},
#   {'name': 'FreeThrow',
#    'player': 'G. Dragic - MIA',
#    'type': None,
#    'outcome': 'make',
#    'relations': {'Fouler': 'K. Irving - BOS'},
#    'attributes': None},
#   {'name': 'TryPt',
#    'player': 'M. Smart - BOS',
#    'type': '3-pt jump shot',
#    'outcome': 'make',
#    'relations': {'AssistedBy': 'J. Tatum - BOS'},
#    'attributes': {'Dist': 23}},
#   {'name': 'TryPt',
#    'player': 'G. Dragic - MIA',
#    'type': '2-pt layup',
#    'outcome': 'make',
#    'relations': None,
#    'attributes': {'Dist': 0}},
#   {'name': 'Turnover',
#    'player': 'K. Irving - BOS',
#    'type': 'lost ball',
#    'outcome': None,
#    'relations': {'StolenBy': 'K. Olynyk - MIA'},
#    'attributes': None},
#   {'name': 'Turnover',
#    'player': 'J. Johnson - MIA',
#    'type': 'bad pass',
#    'outcome': None,
#    'relations': {'StolenBy': 'M. Smart - BOS'},
#    'attributes': None},
#   {'name': 'Foul',
#    'player': 'D. Waiters - MIA',
#    'type': 'shooting',
#    'outcome': None,
#    'relations': {'Fouled': 'A. Horford - BOS'},
#    'attributes': None},
#   {'name': 'FreeThrow',
#    'player': 'A. Horford - BOS',
#    'type': None,
#    'outcome': 'make',
#    'relations': {'Fouler': 'D. Waiters - MIA'},
#    'attributes': None},
#   {'name': 'Enter',
#    'player': 'G. Hayward - BOS',
#    'type': None,
#    'outcome': None,
#    'relations': {'Replace': 'J. Tatum - BOS'},
#    'attributes': None},
#   {'name': 'FreeThrow',
#    'player': 'A. Horford - BOS',
#    'type': None,
#    'outcome': 'make',
#    'relations': {'Fouler': 'D. Waiters - MIA'},
#    'attributes': None},
#   {'name': 'TryPt',
#    'player': 'J. Johnson - MIA',
#    'type': '3-pt jump shot',
#    'outcome': 'miss',
#    'relations': None,
#    'attributes': {'Dist': 24}},
#   {'name': 'Rebound',
#    'player': 'B. Adebayo - MIA',
#    'type': 'offensive',
#    'outcome': None,
#    'relations': None,
#    'attributes': None},
#   {'name': 'TryPt',
#    'player': 'G. Dragic - MIA',
#    'type': '3-pt jump shot',
#    'outcome': 'make',
#    'relations': {'AssistedBy': 'D. Waiters - MIA'},
#    'attributes': {'Dist': 25}},
#   {'name': 'Enter',
#    'player': 'M. Morris - BOS',
#    'type': None,
#    'outcome': None,
#    'relations': {'Replace': 'D. Theis - BOS'},
#    'attributes': None},
#   {'name': 'TryPt',
#    'player': 'M. Morris - BOS',
#    'type': '2-pt jump shot',
#    'outcome': 'miss',
#    'relations': None,
#    'attributes': {'Dist': 18}},
#   {'name': 'Rebound',
#    'player': 'B. Adebayo - MIA',
#    'type': 'defensive',
#    'outcome': None,
#    'relations': None,
#    'attributes': None},
#   {'name': 'Turnover',
#    'player': 'G. Dragic - MIA',
#    'type': 'bad pass',
#    'outcome': None,
#    'relations': {'StolenBy': 'A. Horford - BOS'},
#    'attributes': None},
#   {'name': 'TryPt',
#    'player': 'M. Smart - BOS',
#    'type': '3-pt jump shot',
#    'outcome': 'miss',
#    'relations': None,
#    'attributes': {'Dist': 24}},
#   {'name': 'Rebound',
#    'player': 'J. Johnson - MIA',
#    'type': 'defensive',
#    'outcome': None,
#    'relations': None,
#    'attributes': None},
#   {'name': 'TryPt',
#    'player': 'B. Adebayo - MIA',
#    'type': '2-pt dunk',
#    'outcome': 'make',
#    'relations': {'AssistedBy': 'G. Dragic - MIA'},
#    'attributes': {'Dist': 0}},
#   {'name': 'TryPt',
#    'player': 'M. Smart - BOS',
#    'type': '2-pt jump shot',
#    'outcome': 'miss',
#    'relations': None,
#    'attributes': {'Dist': 14}},
#   {'name': 'Rebound',
#    'player': 'A. Horford - BOS',
#    'type': 'offensive',
#    'outcome': None,
#    'relations': None,
#    'attributes': None},
#   {'name': 'TryPt',
#    'player': 'A. Horford - BOS',
#    'type': '2-pt layup',
#    'outcome': 'make',
#    'relations': None,
#    'attributes': {'Dist': 2}},
#   {'name': 'Foul',
#    'player': 'K. Irving - BOS',
#    'type': 'personal',
#    'outcome': None,
#    'relations': {'Fouled': 'G. Dragic - MIA'},
#    'attributes': None},
#   {'name': 'Turnover',
#    'player': 'K. Olynyk - MIA',
#    'type': 'step out of bounds',
#    'outcome': None,
#    'relations': None,
#    'attributes': None},
#   {'name': 'Turnover',
#    'player': 'K. Irving - BOS',
#    'type': 'bad pass',
#    'outcome': None,
#    'relations': {'StolenBy': 'G. Dragic - MIA'},
#    'attributes': None},
#   {'name': 'Turnover',
#    'player': 'G. Dragic - MIA',
#    'type': 'out of bounds lost ball',
#    'outcome': None,
#    'relations': None,
#    'attributes': None},
#   {'name': 'TryPt',
#    'player': 'G. Hayward - BOS',
#    'type': '3-pt jump shot',
#    'outcome': 'make',
#    'relations': {'AssistedBy': 'K. Irving - BOS'},
#    'attributes': {'Dist': 26}},
#   {'name': 'TryPt',
#    'player': 'K. Olynyk - MIA',
#    'type': '2-pt layup',
#    'outcome': 'make',
#    'relations': {'AssistedBy': 'J. Johnson - MIA'},
#    'attributes': {'Dist': 1}},
#   {'name': 'Foul',
#    'player': 'G. Dragic - MIA',
#    'type': 'personal',
#    'outcome': None,
#    'relations': {'Fouled': 'K. Irving - BOS'},
#    'attributes': None},
#   {'name': 'Enter',
#    'player': 'D. Wade - MIA',
#    'type': None,
#    'outcome': None,
#    'relations': {'Replace': 'G. Dragic - MIA'},
#    'attributes': None},
#   {'name': 'TryPt',
#    'player': 'K. Irving - BOS',
#    'type': '3-pt jump shot',
#    'outcome': 'make',
#    'relations': {'AssistedBy': 'M. Smart - BOS'},
#    'attributes': {'Dist': 24}},
#   {'name': 'Foul',
#    'player': 'M. Smart - BOS',
#    'type': 'personal',
#    'outcome': None,
#    'relations': {'Fouled': 'D. Wade - MIA'},
#    'attributes': None},
#   {'name': 'TryPt',
#    'player': 'D. Waiters - MIA',
#    'type': '3-pt jump shot',
#    'outcome': 'make',
#    'relations': {'AssistedBy': 'K. Olynyk - MIA'},
#    'attributes': {'Dist': 24}},
#   {'name': 'TryPt',
#    'player': 'K. Irving - BOS',
#    'type': '2-pt jump shot',
#    'outcome': 'miss',
#    'relations': None,
#    'attributes': {'Dist': 13}},
#   {'name': 'Rebound',
#    'player': 'J. Johnson - MIA',
#    'type': 'defensive',
#    'outcome': None,
#    'relations': None,
#    'attributes': None},
#   {'name': 'Turnover',
#    'player': 'K. Olynyk - MIA',
#    'type': 'traveling',
#    'outcome': None,
#    'relations': None,
#    'attributes': None},
#   {'name': 'TryPt',
#    'player': 'M. Smart - BOS',
#    'type': '2-pt layup',
#    'outcome': 'make',
#    'relations': None,
#    'attributes': {'Dist': 2}},
#   {'name': 'TryPt',
#    'player': 'B. Adebayo - MIA',
#    'type': '2-pt dunk',
#    'outcome': 'make',
#    'relations': {'AssistedBy': 'D. Wade - MIA'},
#    'attributes': {'Dist': 0}},
#   {'name': 'TryPt',
#    'player': 'A. Horford - BOS',
#    'type': '2-pt layup',
#    'outcome': 'miss',
#    'relations': {'BlockedBy': 'K. Olynyk - MIA'},
#    'attributes': {'Dist': 3}},
#   {'name': 'Rebound',
#    'player': 'A. Horford - BOS',
#    'type': 'offensive',
#    'outcome': None,
#    'relations': None,
#    'attributes': None},
#   {'name': 'TryPt',
#    'player': 'A. Horford - BOS',
#    'type': '2-pt layup',
#    'outcome': 'make',
#    'relations': None,
#    'attributes': {'Dist': 1}},
#   {'name': 'TryPt',
#    'player': 'K. Olynyk - MIA',
#    'type': '3-pt jump shot',
#    'outcome': 'miss',
#    'relations': None,
#    'attributes': {'Dist': 25}},
#   {'name': 'Rebound',
#    'player': 'A. Horford - BOS',
#    'type': 'defensive',
#    'outcome': None,
#    'relations': None,
#    'attributes': None},
#   {'name': 'TryPt',
#    'player': 'K. Irving - BOS',
#    'type': '3-pt jump shot',
#    'outcome': 'miss',
#    'relations': None,
#    'attributes': {'Dist': 33}},
#   {'name': 'Rebound',
#    'player': 'M. Morris - BOS',
#    'type': 'offensive',
#    'outcome': None,
#    'relations': None,
#    'attributes': None},
#   {'name': 'TryPt',
#    'player': 'M. Morris - BOS',
#    'type': '2-pt layup',
#    'outcome': 'miss',
#    'relations': None,
#    'attributes': {'Dist': 0}},
#   {'name': 'Rebound',
#    'player': 'D. Wade - MIA',
#    'type': 'defensive',
#    'outcome': None,
#    'relations': None,
#    'attributes': None},
#   {'name': 'Foul',
#    'player': 'D. Waiters - MIA',
#    'type': 'offensive',
#    'outcome': None,
#    'relations': {'Fouled': 'M. Smart - BOS'},
#    'attributes': None},
#   {'name': 'Turnover',
#    'player': 'D. Waiters - MIA',
#    'type': 'offensive foul',
#    'outcome': None,
#    'relations': None,
#    'attributes': None},
#   {'name': 'Enter',
#    'player': 'G. Dragic - MIA',
#    'type': None,
#    'outcome': None,
#    'relations': {'Replace': 'D. Waiters - MIA'},
#    'attributes': None},
#   {'name': 'Enter',
#    'player': 'T. Rozier - BOS',
#    'type': None,
#    'outcome': None,
#    'relations': {'Replace': 'K. Irving - BOS'},
#    'attributes': None},
#   {'name': 'Enter',
#    'player': 'J. Tatum - BOS',
#    'type': None,
#    'outcome': None,
#    'relations': {'Replace': 'M. Smart - BOS'},
#    'attributes': None},
#   {'name': 'TryPt',
#    'player': 'A. Horford - BOS',
#    'type': '2-pt layup',
#    'outcome': 'miss',
#    'relations': None,
#    'attributes': {'Dist': 3}},
#   {'name': 'Rebound',
#    'player': 'G. Hayward - BOS',
#    'type': 'offensive',
#    'outcome': None,
#    'relations': None,
#    'attributes': None},
#   {'name': 'TryPt',
#    'player': 'G. Hayward - BOS',
#    'type': '2-pt layup',
#    'outcome': 'miss',
#    'relations': None,
#    'attributes': {'Dist': 0}},
#   {'name': 'Rebound',
#    'player': 'K. Olynyk - MIA',
#    'type': 'defensive',
#    'outcome': None,
#    'relations': None,
#    'attributes': None},
# ...
#    'player': 'A. Baynes - BOS',
#    'type': '2-pt jump shot',
#    'outcome': 'miss',
#    'relations': None,
#    'attributes': {'Dist': 14}},
#   {'name': 'Rebound',
#    'player': 'H. Whiteside - MIA',
#    'type': 'defensive',
#    'outcome': None,
#    'relations': None,
#    'attributes': None},
#   {'name': 'TryPt',
#    'player': 'J. Johnson - MIA',
#    'type': '3-pt jump shot',
#    'outcome': 'miss',
#    'relations': None,
#    'attributes': {'Dist': 23}},
#   {'name': 'Rebound',
#    'player': 'J. Tatum - BOS',
#    'type': 'defensive',
#    'outcome': None,
#    'relations': None,
#    'attributes': None},
#   {'name': 'TryPt',
#    'player': 'A. Baynes - BOS',
#    'type': '2-pt layup',
#    'outcome': 'miss',
#    'relations': None,
#    'attributes': {'Dist': 12}},
#   {'name': 'Rebound',
#    'player': 'H. Whiteside - MIA',
#    'type': 'defensive',
#    'outcome': None,
#    'relations': None,
#    'attributes': None},
#   {'name': 'Turnover',
#    'player': 'D. Wade - MIA',
#    'type': 'bad pass',
#    'outcome': None,
#    'relations': {'StolenBy': 'J. Tatum - BOS'},
#    'attributes': None},
#   {'name': 'TryPt',
#    'player': 'M. Morris - BOS',
#    'type': '3-pt jump shot',
#    'outcome': 'miss',
#    'relations': None,
#    'attributes': {'Dist': 26}},
#   {'name': 'Rebound',
#    'player': 'K. Olynyk - MIA',
#    'type': 'defensive',
#    'outcome': None,
#    'relations': None,
#    'attributes': None},
#   {'name': 'TryPt',
#    'player': 'G. Dragic - MIA',
#    'type': '3-pt jump shot',
#    'outcome': 'miss',
#    'relations': None,
#    'attributes': {'Dist': 26}},
#   {'name': 'Rebound',
#    'player': 'G. Hayward - BOS',
#    'type': 'defensive',
#    'outcome': None,
#    'relations': None,
#    'attributes': None},
#   {'name': 'Enter',
#    'player': 'D. Waiters - MIA',
#    'type': None,
#    'outcome': None,
#    'relations': {'Replace': 'J. Johnson - MIA'},
#    'attributes': None},
#   {'name': 'TryPt',
#    'player': 'G. Hayward - BOS',
#    'type': '2-pt layup',
#    'outcome': 'make',
#    'relations': {'AssistedBy': 'T. Rozier - BOS'},
#    'attributes': {'Dist': 2}},
#   {'name': 'TryPt',
#    'player': 'D. Wade - MIA',
#    'type': '2-pt layup',
#    'outcome': 'miss',
#    'relations': None,
#    'attributes': {'Dist': 3}},
#   {'name': 'Rebound',
#    'player': 'A. Baynes - BOS',
#    'type': 'defensive',
#    'outcome': None,
#    'relations': None,
#    'attributes': None},
#   {'name': 'TryPt',
#    'player': 'M. Morris - BOS',
#    'type': '2-pt jump shot',
#    'outcome': 'miss',
#    'relations': None,
#    'attributes': {'Dist': 13}},
#   {'name': 'Rebound',
#    'player': 'A. Baynes - BOS',
#    'type': 'offensive',
#    'outcome': None,
#    'relations': None,
#    'attributes': None},
#   {'name': 'TryPt',
#    'player': 'A. Baynes - BOS',
#    'type': '2-pt layup',
#    'outcome': 'miss',
#    'relations': None,
#    'attributes': {'Dist': 1}},
#   {'name': 'Rebound',
#    'player': 'H. Whiteside - MIA',
#    'type': 'defensive',
#    'outcome': None,
#    'relations': None,
#    'attributes': None},
#   {'name': 'TryPt',
#    'player': 'K. Olynyk - MIA',
#    'type': '3-pt jump shot',
#    'outcome': 'make',
#    'relations': {'AssistedBy': 'G. Dragic - MIA'},
#    'attributes': {'Dist': 26}},
#   {'name': 'TryPt',
#    'player': 'A. Baynes - BOS',
#    'type': '2-pt layup',
#    'outcome': 'miss',
#    'relations': {'BlockedBy': 'H. Whiteside - MIA'},
#    'attributes': {'Dist': 2}},
#   {'name': 'Rebound',
#    'player': 'H. Whiteside - MIA',
#    'type': 'defensive',
#    'outcome': None,
#    'relations': None,
#    'attributes': None},
#   {'name': 'TryPt',
#    'player': 'G. Dragic - MIA',
#    'type': '2-pt layup',
#    'outcome': 'make',
#    'relations': {'AssistedBy': 'D. Wade - MIA'},
#    'attributes': {'Dist': 1}},
#   {'name': 'TryPt',
#    'player': 'M. Morris - BOS',
#    'type': '2-pt jump shot',
#    'outcome': 'make',
#    'relations': {'AssistedBy': 'J. Tatum - BOS'},
#    'attributes': {'Dist': 16}},
#   {'name': 'TryPt',
#    'player': 'D. Wade - MIA',
#    'type': '2-pt jump shot',
#    'outcome': 'make',
#    'relations': None,
#    'attributes': {'Dist': 3}},
#   {'name': 'TryPt',
#    'player': 'M. Morris - BOS',
#    'type': '2-pt hook shot',
#    'outcome': 'miss',
#    'relations': {'BlockedBy': 'H. Whiteside - MIA'},
#    'attributes': {'Dist': 4}},
#   {'name': 'Rebound',
#    'player': 'D. Wade - MIA',
#    'type': 'defensive',
#    'outcome': None,
#    'relations': None,
#    'attributes': None},
#   {'name': 'Foul',
#    'player': 'T. Rozier - BOS',
#    'type': 'shooting',
#    'outcome': None,
#    'relations': {'Fouled': 'K. Olynyk - MIA'},
#    'attributes': None},
#   {'name': 'FreeThrow',
#    'player': 'K. Olynyk - MIA',
#    'type': None,
#    'outcome': 'make',
#    'relations': {'Fouler': 'T. Rozier - BOS'},
#    'attributes': None},
#   {'name': 'FreeThrow',
#    'player': 'K. Olynyk - MIA',
#    'type': None,
#    'outcome': 'make',
#    'relations': {'Fouler': 'T. Rozier - BOS'},
#    'attributes': None},
#   {'name': 'Enter',
#    'player': 'A. Horford - BOS',
#    'type': None,
#    'outcome': None,
#    'relations': {'Replace': 'G. Hayward - BOS'},
#    'attributes': None},
#   {'name': 'Enter',
#    'player': 'K. Irving - BOS',
#    'type': None,
#    'outcome': None,
#    'relations': {'Replace': 'M. Morris - BOS'},
#    'attributes': None},
#   {'name': 'FreeThrow',
#    'player': 'K. Olynyk - MIA',
#    'type': None,
#    'outcome': 'make',
#    'relations': {'Fouler': 'T. Rozier - BOS'},
#    'attributes': None},
#   {'name': 'TryPt',
#    'player': 'J. Tatum - BOS',
#    'type': '3-pt jump shot',
#    'outcome': 'make',
#    'relations': {'AssistedBy': 'A. Horford - BOS'},
#    'attributes': {'Dist': 25}},
#   {'name': 'TryPt',
#    'player': 'K. Olynyk - MIA',
#    'type': '3-pt jump shot',
#    'outcome': 'miss',
#    'relations': None,
#    'attributes': {'Dist': 25}},
#   {'name': 'TryPt',
#    'player': 'K. Irving - BOS',
#    'type': '3-pt jump shot',
#    'outcome': 'miss',
#    'relations': None,
#    'attributes': {'Dist': 26}},
#   {'name': 'Rebound',
#    'player': 'K. Olynyk - MIA',
#    'type': 'defensive',
#    'outcome': None,
#    'relations': None,
#    'attributes': None},
#   {'name': 'TryPt',
#    'player': 'D. Waiters - MIA',
#    'type': '3-pt jump shot',
#    'outcome': 'miss',
#    'relations': None,
#    'attributes': {'Dist': 25}},
#   {'name': 'Rebound',
#    'player': 'K. Irving - BOS',
#    'type': 'defensive',
#    'outcome': None,
#    'relations': None,
#    'attributes': None},
#   {'name': 'TryPt',
#    'player': 'T. Rozier - BOS',
#    'type': '3-pt jump shot',
#    'outcome': 'make',
#    'relations': {'AssistedBy': 'K. Irving - BOS'},
#    'attributes': {'Dist': 25}},
#   {'name': 'TryPt',
#    'player': 'D. Wade - MIA',
#    'type': '3-pt jump shot',
#    'outcome': 'miss',
#    'relations': None,
#    'attributes': {'Dist': 24}},
#   {'name': 'Rebound',
#    'player': 'T. Rozier - BOS',
#    'type': 'defensive',
#    'outcome': None,
#    'relations': None,
#    'attributes': None},
#   {'name': 'Turnover',
#    'player': 'Team - MIA',
#    'type': 'shot clock',
#    'outcome': None,
#    'relations': None,
#    'attributes': None},
#   {'name': 'Enter',
#    'player': 'B. Adebayo - MIA',
#    'type': None,
#    'outcome': None,
#    'relations': {'Replace': 'H. Whiteside - MIA'},
#    'attributes': None},
#   {'name': 'TryPt',
#    'player': 'K. Olynyk - MIA',
#    'type': '3-pt jump shot',
#    'outcome': 'miss',
#    'relations': None,
#    'attributes': {'Dist': 25}},
#   {'name': 'Rebound',
#    'player': 'K. Irving - BOS',
#    'type': 'defensive',
#    'outcome': None,
#    'relations': None,
#    'attributes': None},
#   {'name': 'TryPt',
#    'player': 'T. Rozier - BOS',
#    'type': '3-pt jump shot',
#    'outcome': 'miss',
#    'relations': None,
#    'attributes': {'Dist': 27}},
#   {'name': 'Rebound',
#    'player': 'K. Olynyk - MIA',
#    'type': 'defensive',
#    'outcome': None,
#    'relations': None,
#    'attributes': None},
#   {'name': 'Foul',
#    'player': 'K. Irving - BOS',
#    'type': 'shooting',
#    'outcome': None,
#    'relations': {'Fouled': 'D. Waiters - MIA'},
#    'attributes': None},
#   {'name': 'FreeThrow',
#    'player': 'D. Waiters - MIA',
#    'type': None,
#    'outcome': 'make',
#    'relations': {'Fouler': 'K. Irving - BOS'},
#    'attributes': None},
#   {'name': 'FreeThrow',
#    'player': 'D. Waiters - MIA',
#    'type': None,
#    'outcome': 'make',
#    'relations': {'Fouler': 'K. Irving - BOS'},
#    'attributes': None},
#   {'name': 'Turnover',
#    'player': 'T. Rozier - BOS',
#    'type': 'lost ball',
#    'outcome': None,
#    'relations': {'StolenBy': 'D. Waiters - MIA'},
#    'attributes': None},
#   {'name': 'TryPt',
#    'player': 'D. Waiters - MIA',
#    'type': '2-pt layup',
#    'outcome': 'make',
#    'relations': None,
#    'attributes': {'Dist': 1}},
#   {'name': 'TryPt',
#    'player': 'J. Tatum - BOS',
#    'type': '2-pt layup',
#    'outcome': 'miss',
#    'relations': None,
#    'attributes': {'Dist': 4}},
#   {'name': 'Rebound',
#    'player': 'A. Baynes - BOS',
#    'type': 'offensive',
#    'outcome': None,
#    'relations': None,
#    'attributes': None},
#   {'name': 'TryPt',
#    'player': 'A. Baynes - BOS',
#    'type': '2-pt layup',
#    'outcome': 'miss',
#    'relations': None,
#    'attributes': {'Dist': 0}},
#   {'name': 'Rebound',
#    'player': 'A. Baynes - BOS',
#    'type': 'offensive',
#    'outcome': None,
#    'relations': None,
#    'attributes': None},
#   {'name': 'TryPt',
#    'player': 'A. Horford - BOS',
#    'type': '3-pt jump shot',
#    'outcome': 'miss',
#    'relations': None,
#    'attributes': {'Dist': 26}},
#   {'name': 'Rebound',
#    'player': 'K. Irving - BOS',
#    'type': 'offensive',
#    'outcome': None,
#    'relations': None,
#    'attributes': None},
#   {'name': 'TryPt',
#    'player': 'T. Rozier - BOS',
#    'type': '3-pt jump shot',
#    'outcome': 'miss',
#    'relations': None,
#    'attributes': {'Dist': 25}},
#   {'name': 'Enter',
#    'player': 'H. Whiteside - MIA',
#    'type': None,
#    'outcome': None,
#    'relations': {'Replace': 'B. Adebayo - MIA'},
#    'attributes': None},
#   {'name': 'Enter',
#    'player': 'M. Smart - BOS',
#    'type': None,
#    'outcome': None,
#    'relations': {'Replace': 'T. Rozier - BOS'},
#    'attributes': None},
#   {'name': 'Foul',
#    'player': 'D. Wade - MIA',
#    'type': 'personal',
#    'outcome': None,
#    'relations': {'Fouled': 'A. Horford - BOS'},
#    'attributes': None},
#   {'name': 'TryPt',
#    'player': 'J. Tatum - BOS',
#    'type': '2-pt jump shot',
#    'outcome': 'make',
#    'relations': {'AssistedBy': 'A. Horford - BOS'},
#    'attributes': {'Dist': 15}},
#   {'name': 'TryPt',
#    'player': 'G. Dragic - MIA',
#    'type': '2-pt jump shot',
#    'outcome': 'make',
#    'relations': {'AssistedBy': 'H. Whiteside - MIA'},
#    'attributes': {'Dist': 8}},
#   {'name': 'Enter',
#    'player': 'G. Hayward - BOS',
#    'type': None,
#    'outcome': None,
#    'relations': {'Replace': 'A. Baynes - BOS'},
#    'attributes': None},
#   {'name': 'Turnover',
#    'player': 'K. Irving - BOS',
#    'type': 'bad pass',
#    'outcome': None,
#    'relations': {'StolenBy': 'G. Dragic - MIA'},
#    'attributes': None},
#   {'name': 'TryPt',
#    'player': 'D. Wade - MIA',
#    'type': '2-pt jump shot',
#    'outcome': 'make',
#    'relations': {'AssistedBy': 'D. Waiters - MIA'},
#    'attributes': {'Dist': 15}},
#   {'name': 'TryPt',
#    'player': 'K. Irving - BOS',
#    'type': '3-pt jump shot',
#    'outcome': 'miss',
#    'relations': None,
#    'attributes': {'Dist': 26}},
#   {'name': 'Rebound',
#    'player': 'H. Whiteside - MIA',
#    'type': 'defensive',
#    'outcome': None,
#    'relations': None,
#    'attributes': None},
#   {'name': 'TryPt',
#    'player': 'D. Waiters - MIA',
#    'type': '3-pt jump shot',
#    'outcome': 'miss',
#    'relations': None,
#    'attributes': {'Dist': 26}},
#   {'name': 'Rebound',
#    'player': 'A. Horford - BOS',
#    'type': 'defensive',
#    'outcome': None,
#    'relations': None,
#    'attributes': None},
#   {'name': 'TryPt',
#    'player': 'K. Irving - BOS',
#    'type': '2-pt layup',
#    'outcome': 'make',
#    'relations': None,
#    'attributes': {'Dist': 3}},
#   {'name': 'Foul',
#    'player': 'K. Olynyk - MIA',
#    'type': 'shooting',
#    'outcome': None,
#    'relations': {'Fouled': 'K. Irving - BOS'},
#    'attributes': None},
#   {'name': 'Enter',
#    'player': 'B. Adebayo - MIA',
#    'type': None,
#    'outcome': None,
#    'relations': {'Replace': 'H. Whiteside - MIA'},
#    'attributes': None},
#   {'name': 'FreeThrow',
#    'player': 'K. Irving - BOS',
#    'type': None,
#    'outcome': 'make',
#    'relations': {'Fouler': 'K. Olynyk - MIA'},
#    'attributes': None},
#   {'name': 'TryPt',
#    'player': 'D. Wade - MIA',
#    'type': '3-pt jump shot',
#    'outcome': 'miss',
#    'relations': None,
#    'attributes': {'Dist': 26}},
#   {'name': 'Rebound',
#    'player': 'G. Hayward - BOS',
#    'type': 'defensive',
#    'outcome': None,
#    'relations': None,
#    'attributes': None},
#   {'name': 'Turnover',
#    'player': 'K. Irving - BOS',
#    'type': 'bad pass',
#    'outcome': None,
#    'relations': None,
#    'attributes': None},
#   {'name': 'TryPt',
#    'player': 'G. Dragic - MIA',
#    'type': '3-pt jump shot',
#    'outcome': 'miss',
#    'relations': None,
#    'attributes': {'Dist': 26}},
#   {'name': 'Rebound',
#    'player': 'D. Wade - MIA',
#    'type': 'offensive',
#    'outcome': None,
#    'relations': None,
#    'attributes': None},
#   {'name': 'TryPt',
#    'player': 'D. Wade - MIA',
#    'type': '2-pt layup',
#    'outcome': 'miss',
#    'relations': None,
#    'attributes': {'Dist': 1}},
#   {'name': 'Rebound',
#    'player': 'D. Wade - MIA',
#    'type': 'offensive',
#    'outcome': None,
#    'relations': None,
#    'attributes': None},
#   {'name': 'TryPt',
#    'player': 'D. Wade - MIA',
#    'type': '2-pt layup',
#    'outcome': 'make',
#    'relations': None,
#    'attributes': {'Dist': 1}},
#   {'name': 'TryPt',
#    'player': 'K. Irving - BOS',
#    'type': '3-pt jump shot',
#    'outcome': 'miss',
#    'relations': None,
#    'attributes': {'Dist': 26}},
#   {'name': 'Turnover',
#    'player': 'K. Olynyk - MIA',
#    'type': 'bad pass',
#    'outcome': None,
#    'relations': None,
#    'attributes': None},
#   {'name': 'Foul',
#    'player': 'D. Wade - MIA',
#    'type': 'personal take',
#    'outcome': None,
#    'relations': {'Fouled': 'K. Irving - BOS'},
#    'attributes': None},
#   {'name': 'FreeThrow',
#    'player': 'K. Irving - BOS',
#    'type': None,
#    'outcome': 'make',
#    'relations': {'Fouler': 'D. Wade - MIA'},
#    'attributes': None},
#   {'name': 'FreeThrow',
#    'player': 'K. Irving - BOS',
#    'type': None,
#    'outcome': 'make',
#    'relations': {'Fouler': 'D. Wade - MIA'},
#    'attributes': None},
#   {'name': 'TryPt',
#    'player': 'D. Wade - MIA',
#    'type': '3-pt jump shot',
#    'outcome': 'miss',
#    'relations': None,
#    'attributes': {'Dist': 27}},
#   {'name': 'Rebound',
#    'player': 'B. Adebayo - MIA',
#    'type': 'offensive',
#    'outcome': None,
#    'relations': None,
#    'attributes': None},
#   {'name': 'TryPt',
#    'player': 'K. Olynyk - MIA',
#    'type': '3-pt jump shot',
#    'outcome': 'miss',
#    'relations': None,
#    'attributes': {'Dist': 25}},
#   {'name': 'Rebound',
#    'player': 'A. Horford - BOS',
#    'type': 'defensive',
#    'outcome': None,
#    'relations': None,
#    'attributes': None},
#   {'name': 'Foul',
#    'player': 'G. Dragic - MIA',
#    'type': 'personal take',
#    'outcome': None,
#    'relations': {'Fouled': 'A. Horford - BOS'},
#    'attributes': None},
#   {'name': 'FreeThrow',
#    'player': 'A. Horford - BOS',
#    'type': None,
#    'outcome': 'make',
#    'relations': {'Fouler': 'G. Dragic - MIA'},
#    'attributes': None},
#   {'name': 'Enter',
#    'player': 'S. Ojeleye - BOS',
#    'type': None,
#    'outcome': None,
#    'relations': {'Replace': 'K. Irving - BOS'},
#    'attributes': None},
#   {'name': 'FreeThrow',
#    'player': 'A. Horford - BOS',
#    'type': None,
#    'outcome': 'make',
#    'relations': {'Fouler': 'G. Dragic - MIA'},
#    'attributes': None},
#   {'name': 'TryPt',
#    'player': 'B. Adebayo - MIA',
#    'type': '3-pt jump shot',
#    'outcome': 'make',
#    'relations': {'AssistedBy': 'D. Waiters - MIA'},
#    'attributes': {'Dist': 25}}],
#  'players': ['K. Olynyk - MIA',
#   'T. Rozier - BOS',
#   'A. Horford - BOS',
#   'D. Waiters - MIA',
#   'G. Dragic - MIA',
#   'Team - MIA',
#   'D. Theis - BOS',
#   'S. Ojeleye - BOS',
#   'G. Yabusele - BOS',
#   'D. Wade - MIA',
#   'J. Tatum - BOS',
#   'B. Adebayo - MIA',
#   'J. Johnson - MIA',
#   'K. Irving - BOS',
#   'G. Hayward - BOS',
#   'M. Smart - BOS',
#   'H. Whiteside - MIA',
#   'R. Anderson - MIA',
#   'A. Baynes - BOS',
#   'D. Jones - MIA',
#   'M. Morris - BOS']}

# %%
tatumshots = [event for event in game["events"] if event["player"] == "J. Tatum - BOS" and event["name"]=="TryPt"]

# %%
len([shot for shot in tatumshots if shot['outcome']=='make']), len(tatumshots)
# Out:
# (7, 15)

# %%
[shot for shot in tatumshots if shot['outcome']=='make' and shot['relations'] is not None]
# Out:
# [{'name': 'TryPt',
#   'player': 'J. Tatum - BOS',
#   'type': '2-pt dunk',
#   'outcome': 'make',
#   'relations': {'AssistedBy': 'A. Horford - BOS'},
#   'attributes': {'Dist': 0}},
#  {'name': 'TryPt',
#   'player': 'J. Tatum - BOS',
#   'type': '3-pt jump shot',
#   'outcome': 'make',
#   'relations': {'AssistedBy': 'M. Morris - BOS'},
#   'attributes': {'Dist': 24}},
#  {'name': 'TryPt',
#   'player': 'J. Tatum - BOS',
#   'type': '3-pt jump shot',
#   'outcome': 'make',
#   'relations': {'AssistedBy': 'G. Hayward - BOS'},
#   'attributes': {'Dist': 23}},
#  {'name': 'TryPt',
#   'player': 'J. Tatum - BOS',
#   'type': '3-pt jump shot',
#   'outcome': 'make',
#   'relations': {'AssistedBy': 'A. Horford - BOS'},
#   'attributes': {'Dist': 25}},
#  {'name': 'TryPt',
#   'player': 'J. Tatum - BOS',
#   'type': '2-pt jump shot',
#   'outcome': 'make',
#   'relations': {'AssistedBy': 'A. Horford - BOS'},
#   'attributes': {'Dist': 15}}]

# %%
[event for event in game["events"] if event["name"] == "FreeThrow"]
# Out:
# [{'name': 'FreeThrow',
#   'player': 'J. Tatum - BOS',
#   'type': None,
#   'outcome': 'make',
#   'relations': {'Fouler': 'D. Waiters - MIA'},
#   'attributes': None},
#  {'name': 'FreeThrow',
#   'player': 'J. Tatum - BOS',
#   'type': None,
#   'outcome': 'miss',
#   'relations': {'Fouler': 'D. Waiters - MIA'},
#   'attributes': None},
#  {'name': 'FreeThrow',
#   'player': 'J. Johnson - MIA',
#   'type': None,
#   'outcome': 'miss',
#   'relations': {'Fouler': 'M. Morris - BOS'},
#   'attributes': None},
#  {'name': 'FreeThrow',
#   'player': 'G. Hayward - BOS',
#   'type': None,
#   'outcome': 'make',
#   'relations': {'Fouler': 'G. Dragic - MIA'},
#   'attributes': None},
#  {'name': 'FreeThrow',
#   'player': 'G. Hayward - BOS',
#   'type': None,
#   'outcome': 'make',
#   'relations': {'Fouler': 'G. Dragic - MIA'},
#   'attributes': None},
#  {'name': 'FreeThrow',
#   'player': 'J. Johnson - MIA',
#   'type': None,
#   'outcome': 'make',
#   'relations': {'Fouler': 'A. Baynes - BOS'},
#   'attributes': None},
#  {'name': 'FreeThrow',
#   'player': 'J. Johnson - MIA',
#   'type': None,
#   'outcome': 'make',
#   'relations': {'Fouler': 'A. Baynes - BOS'},
#   'attributes': None},
#  {'name': 'FreeThrow',
#   'player': 'A. Baynes - BOS',
#   'type': None,
#   'outcome': 'make',
#   'relations': {'Fouler': 'H. Whiteside - MIA'},
#   'attributes': None},
#  {'name': 'FreeThrow',
#   'player': 'A. Baynes - BOS',
#   'type': None,
#   'outcome': 'make',
#   'relations': {'Fouler': 'H. Whiteside - MIA'},
#   'attributes': None},
#  {'name': 'FreeThrow',
#   'player': 'A. Baynes - BOS',
#   'type': None,
#   'outcome': 'make',
#   'relations': {'Fouler': 'H. Whiteside - MIA'},
#   'attributes': None},
#  {'name': 'FreeThrow',
#   'player': 'A. Baynes - BOS',
#   'type': None,
#   'outcome': 'make',
#   'relations': {'Fouler': 'H. Whiteside - MIA'},
#   'attributes': None},
#  {'name': 'FreeThrow',
#   'player': 'H. Whiteside - MIA',
#   'type': None,
#   'outcome': 'make',
#   'relations': {'Fouler': 'A. Baynes - BOS'},
#   'attributes': None},
#  {'name': 'FreeThrow',
#   'player': 'H. Whiteside - MIA',
#   'type': None,
#   'outcome': 'miss',
#   'relations': {'Fouler': 'A. Baynes - BOS'},
#   'attributes': None},
#  {'name': 'FreeThrow',
#   'player': 'T. Rozier - BOS',
#   'type': None,
#   'outcome': 'make',
#   'relations': {'Fouler': 'D. Waiters - MIA'},
#   'attributes': None},
#  {'name': 'FreeThrow',
#   'player': 'T. Rozier - BOS',
#   'type': None,
#   'outcome': 'make',
#   'relations': {'Fouler': 'D. Waiters - MIA'},
#   'attributes': None},
#  {'name': 'FreeThrow',
#   'player': 'A. Horford - BOS',
#   'type': None,
#   'outcome': 'make',
#   'relations': {'Fouler': 'J. Johnson - MIA'},
#   'attributes': None},
#  {'name': 'FreeThrow',
#   'player': 'S. Ojeleye - BOS',
#   'type': None,
#   'outcome': 'miss',
#   'relations': {'Fouler': 'B. Adebayo - MIA'},
#   'attributes': None},
#  {'name': 'FreeThrow',
#   'player': 'D. Wade - MIA',
#   'type': None,
#   'outcome': 'make',
#   'relations': {'Fouler': 'A. Baynes - BOS'},
#   'attributes': None},
#  {'name': 'FreeThrow',
#   'player': 'K. Irving - BOS',
#   'type': None,
#   'outcome': 'make',
#   'relations': {'Fouler': 'D. Waiters - MIA'},
#   'attributes': None},
#  {'name': 'FreeThrow',
#   'player': 'D. Theis - BOS',
#   'type': None,
#   'outcome': 'miss',
#   'relations': {'Fouler': 'B. Adebayo - MIA'},
#   'attributes': None},
#  {'name': 'FreeThrow',
#   'player': 'D. Theis - BOS',
#   'type': None,
#   'outcome': 'make',
#   'relations': {'Fouler': 'B. Adebayo - MIA'},
#   'attributes': None},
#  {'name': 'FreeThrow',
#   'player': 'D. Jones - MIA',
#   'type': None,
#   'outcome': 'miss',
#   'relations': {'Fouler': 'A. Horford - BOS'},
#   'attributes': None},
#  {'name': 'FreeThrow',
#   'player': 'D. Jones - MIA',
#   'type': None,
#   'outcome': 'make',
#   'relations': {'Fouler': 'A. Horford - BOS'},
#   'attributes': None},
#  {'name': 'FreeThrow',
#   'player': 'G. Dragic - MIA',
#   'type': None,
#   'outcome': 'make',
#   'relations': {'Fouler': 'M. Smart - BOS'},
#   'attributes': None},
#  {'name': 'FreeThrow',
#   'player': 'G. Dragic - MIA',
#   'type': None,
#   'outcome': 'make',
#   'relations': {'Fouler': 'M. Smart - BOS'},
#   'attributes': None},
#  {'name': 'FreeThrow',
#   'player': 'B. Adebayo - MIA',
#   'type': None,
#   'outcome': 'make',
#   'relations': {'Fouler': 'D. Theis - BOS'},
#   'attributes': None},
#  {'name': 'FreeThrow',
#   'player': 'B. Adebayo - MIA',
#   'type': None,
#   'outcome': 'make',
#   'relations': {'Fouler': 'D. Theis - BOS'},
#   'attributes': None},
#  {'name': 'FreeThrow',
#   'player': 'K. Irving - BOS',
#   'type': None,
#   'outcome': 'make',
#   'relations': {'Fouler': 'D. Jones - MIA'},
#   'attributes': None},
#  {'name': 'FreeThrow',
#   'player': 'K. Irving - BOS',
#   'type': None,
#   'outcome': 'make',
#   'relations': {'Fouler': 'D. Jones - MIA'},
#   'attributes': None},
#  {'name': 'FreeThrow',
#   'player': 'G. Dragic - MIA',
#   'type': None,
#   'outcome': 'make',
#   'relations': {'Fouler': 'K. Irving - BOS'},
#   'attributes': None},
#  {'name': 'FreeThrow',
#   'player': 'A. Horford - BOS',
#   'type': None,
#   'outcome': 'make',
#   'relations': {'Fouler': 'D. Waiters - MIA'},
#   'attributes': None},
#  {'name': 'FreeThrow',
#   'player': 'A. Horford - BOS',
#   'type': None,
#   'outcome': 'make',
#   'relations': {'Fouler': 'D. Waiters - MIA'},
#   'attributes': None},
#  {'name': 'FreeThrow',
#   'player': 'K. Olynyk - MIA',
#   'type': None,
#   'outcome': 'make',
#   'relations': {'Fouler': 'T. Rozier - BOS'},
#   'attributes': None},
#  {'name': 'FreeThrow',
#   'player': 'K. Olynyk - MIA',
#   'type': None,
#   'outcome': 'make',
#   'relations': {'Fouler': 'T. Rozier - BOS'},
#   'attributes': None},
#  {'name': 'FreeThrow',
#   'player': 'K. Olynyk - MIA',
#   'type': None,
#   'outcome': 'make',
#   'relations': {'Fouler': 'T. Rozier - BOS'},
#   'attributes': None},
#  {'name': 'FreeThrow',
#   'player': 'D. Waiters - MIA',
#   'type': None,
#   'outcome': 'make',
#   'relations': {'Fouler': 'K. Irving - BOS'},
#   'attributes': None},
#  {'name': 'FreeThrow',
#   'player': 'D. Waiters - MIA',
#   'type': None,
#   'outcome': 'make',
#   'relations': {'Fouler': 'K. Irving - BOS'},
#   'attributes': None},
#  {'name': 'FreeThrow',
#   'player': 'K. Irving - BOS',
#   'type': None,
#   'outcome': 'make',
#   'relations': {'Fouler': 'K. Olynyk - MIA'},
#   'attributes': None},
#  {'name': 'FreeThrow',
#   'player': 'K. Irving - BOS',
#   'type': None,
#   'outcome': 'make',
#   'relations': {'Fouler': 'D. Wade - MIA'},
#   'attributes': None},
#  {'name': 'FreeThrow',
#   'player': 'K. Irving - BOS',
#   'type': None,
#   'outcome': 'make',
#   'relations': {'Fouler': 'D. Wade - MIA'},
#   'attributes': None},
#  {'name': 'FreeThrow',
#   'player': 'A. Horford - BOS',
#   'type': None,
#   'outcome': 'make',
#   'relations': {'Fouler': 'G. Dragic - MIA'},
#   'attributes': None},
#  {'name': 'FreeThrow',
#   'player': 'A. Horford - BOS',
#   'type': None,
#   'outcome': 'make',
#   'relations': {'Fouler': 'G. Dragic - MIA'},
#   'attributes': None}]

# %%
[event for event in game["events"] if event["name"] == "Enter"]
# Out:
# [{'name': 'Enter',
#   'player': 'J. Johnson - MIA',
#   'type': None,
#   'outcome': None,
#   'relations': {'Replace': 'B. Adebayo - MIA'},
#   'attributes': None},
#  {'name': 'Enter',
#   'player': 'D. Wade - MIA',
#   'type': None,
#   'outcome': None,
#   'relations': {'Replace': 'K. Olynyk - MIA'},
#   'attributes': None},
#  {'name': 'Enter',
#   'player': 'H. Whiteside - MIA',
#   'type': None,
#   'outcome': None,
#   'relations': {'Replace': 'D. Waiters - MIA'},
#   'attributes': None},
#  {'name': 'Enter',
#   'player': 'G. Hayward - BOS',
#   'type': None,
#   'outcome': None,
#   'relations': {'Replace': 'A. Horford - BOS'},
#   'attributes': None},
#  {'name': 'Enter',
#   'player': 'M. Morris - BOS',
#   'type': None,
#   'outcome': None,
#   'relations': {'Replace': 'M. Smart - BOS'},
#   'attributes': None},
#  {'name': 'Enter',
#   'player': 'R. Anderson - MIA',
#   'type': None,
#   'outcome': None,
#   'relations': {'Replace': 'D. Jones - MIA'},
#   'attributes': None},
#  {'name': 'Enter',
#   'player': 'T. Rozier - BOS',
#   'type': None,
#   'outcome': None,
#   'relations': {'Replace': 'K. Irving - BOS'},
#   'attributes': None},
#  {'name': 'Enter',
#   'player': 'D. Waiters - MIA',
#   'type': None,
#   'outcome': None,
#   'relations': {'Replace': 'G. Dragic - MIA'},
#   'attributes': None},
#  {'name': 'Enter',
#   'player': 'A. Horford - BOS',
#   'type': None,
#   'outcome': None,
#   'relations': {'Replace': 'A. Baynes - BOS'},
#   'attributes': None},
#  {'name': 'Enter',
#   'player': 'B. Adebayo - MIA',
#   'type': None,
#   'outcome': None,
#   'relations': {'Replace': 'G. Dragic - MIA'},
#   'attributes': None},
#  {'name': 'Enter',
#   'player': 'D. Wade - MIA',
#   'type': None,
#   'outcome': None,
#   'relations': {'Replace': 'H. Whiteside - MIA'},
#   'attributes': None},
#  {'name': 'Enter',
#   'player': 'D. Jones - MIA',
#   'type': None,
#   'outcome': None,
#   'relations': {'Replace': 'R. Anderson - MIA'},
#   'attributes': None},
#  {'name': 'Enter',
#   'player': 'K. Olynyk - MIA',
#   'type': None,
#   'outcome': None,
#   'relations': {'Replace': 'J. Johnson - MIA'},
#   'attributes': None},
#  {'name': 'Enter',
#   'player': 'A. Baynes - BOS',
#   'type': None,
#   'outcome': None,
#   'relations': {'Replace': 'G. Hayward - BOS'},
#   'attributes': None},
#  {'name': 'Enter',
#   'player': 'K. Irving - BOS',
#   'type': None,
#   'outcome': None,
#   'relations': {'Replace': 'A. Horford - BOS'},
#   'attributes': None},
#  {'name': 'Enter',
#   'player': 'M. Smart - BOS',
#   'type': None,
#   'outcome': None,
#   'relations': {'Replace': 'M. Morris - BOS'},
#   'attributes': None},
#  {'name': 'Enter',
#   'player': 'D. Theis - BOS',
#   'type': None,
#   'outcome': None,
#   'relations': {'Replace': 'A. Baynes - BOS'},
#   'attributes': None},
#  {'name': 'Enter',
#   'player': 'J. Tatum - BOS',
#   'type': None,
#   'outcome': None,
#   'relations': {'Replace': 'S. Ojeleye - BOS'},
#   'attributes': None},
#  {'name': 'Enter',
#   'player': 'G. Yabusele - BOS',
#   'type': None,
#   'outcome': None,
#   'relations': {'Replace': 'T. Rozier - BOS'},
#   'attributes': None},
#  {'name': 'Enter',
#   'player': 'G. Dragic - MIA',
#   'type': None,
#   'outcome': None,
#   'relations': {'Replace': 'D. Wade - MIA'},
#   'attributes': None},
#  {'name': 'Enter',
#   'player': 'A. Horford - BOS',
#   'type': None,
#   'outcome': None,
#   'relations': {'Replace': 'G. Yabusele - BOS'},
#   'attributes': None},
#  {'name': 'Enter',
#   'player': 'G. Hayward - BOS',
#   'type': None,
#   'outcome': None,
#   'relations': {'Replace': 'J. Tatum - BOS'},
#   'attributes': None},
#  {'name': 'Enter',
#   'player': 'D. Wade - MIA',
#   'type': None,
#   'outcome': None,
#   'relations': {'Replace': 'D. Waiters - MIA'},
#   'attributes': None},
#  {'name': 'Enter',
#   'player': 'M. Morris - BOS',
#   'type': None,
#   'outcome': None,
#   'relations': {'Replace': 'D. Theis - BOS'},
#   'attributes': None},
#  {'name': 'Enter',
#   'player': 'D. Waiters - MIA',
#   'type': None,
#   'outcome': None,
#   'relations': {'Replace': 'B. Adebayo - MIA'},
#   'attributes': None},
#  {'name': 'Enter',
#   'player': 'H. Whiteside - MIA',
#   'type': None,
#   'outcome': None,
#   'relations': {'Replace': 'D. Jones - MIA'},
#   'attributes': None},
#  {'name': 'Enter',
#   'player': 'D. Theis - BOS',
#   'type': None,
#   'outcome': None,
#   'relations': {'Replace': 'A. Baynes - BOS'},
#   'attributes': None},
#  {'name': 'Enter',
#   'player': 'G. Hayward - BOS',
#   'type': None,
#   'outcome': None,
#   'relations': {'Replace': 'J. Tatum - BOS'},
#   'attributes': None},
#  {'name': 'Enter',
#   'player': 'M. Morris - BOS',
#   'type': None,
#   'outcome': None,
#   'relations': {'Replace': 'D. Theis - BOS'},
#   'attributes': None},
#  {'name': 'Enter',
#   'player': 'D. Wade - MIA',
#   'type': None,
#   'outcome': None,
#   'relations': {'Replace': 'G. Dragic - MIA'},
#   'attributes': None},
#  {'name': 'Enter',
#   'player': 'G. Dragic - MIA',
#   'type': None,
#   'outcome': None,
#   'relations': {'Replace': 'D. Waiters - MIA'},
#   'attributes': None},
#  {'name': 'Enter',
#   'player': 'T. Rozier - BOS',
#   'type': None,
#   'outcome': None,
#   'relations': {'Replace': 'K. Irving - BOS'},
#   'attributes': None},
#  {'name': 'Enter',
#   'player': 'J. Tatum - BOS',
#   'type': None,
#   'outcome': None,
#   'relations': {'Replace': 'M. Smart - BOS'},
#   'attributes': None},
#  {'name': 'Enter',
#   'player': 'H. Whiteside - MIA',
#   'type': None,
#   'outcome': None,
#   'relations': {'Replace': 'B. Adebayo - MIA'},
#   'attributes': None},
#  {'name': 'Enter',
#   'player': 'A. Baynes - BOS',
#   'type': None,
#   'outcome': None,
#   'relations': {'Replace': 'A. Horford - BOS'},
#   'attributes': None},
#  {'name': 'Enter',
#   'player': 'D. Waiters - MIA',
#   'type': None,
#   'outcome': None,
#   'relations': {'Replace': 'J. Johnson - MIA'},
#   'attributes': None},
#  {'name': 'Enter',
#   'player': 'A. Horford - BOS',
#   'type': None,
#   'outcome': None,
#   'relations': {'Replace': 'G. Hayward - BOS'},
#   'attributes': None},
#  {'name': 'Enter',
#   'player': 'K. Irving - BOS',
#   'type': None,
#   'outcome': None,
#   'relations': {'Replace': 'M. Morris - BOS'},
#   'attributes': None},
#  {'name': 'Enter',
#   'player': 'B. Adebayo - MIA',
#   'type': None,
#   'outcome': None,
#   'relations': {'Replace': 'H. Whiteside - MIA'},
#   'attributes': None},
#  {'name': 'Enter',
#   'player': 'H. Whiteside - MIA',
#   'type': None,
#   'outcome': None,
#   'relations': {'Replace': 'B. Adebayo - MIA'},
#   'attributes': None},
#  {'name': 'Enter',
#   'player': 'M. Smart - BOS',
#   'type': None,
#   'outcome': None,
#   'relations': {'Replace': 'T. Rozier - BOS'},
#   'attributes': None},
#  {'name': 'Enter',
#   'player': 'G. Hayward - BOS',
#   'type': None,
#   'outcome': None,
#   'relations': {'Replace': 'A. Baynes - BOS'},
#   'attributes': None},
#  {'name': 'Enter',
#   'player': 'B. Adebayo - MIA',
#   'type': None,
#   'outcome': None,
#   'relations': {'Replace': 'H. Whiteside - MIA'},
#   'attributes': None},
#  {'name': 'Enter',
#   'player': 'S. Ojeleye - BOS',
#   'type': None,
#   'outcome': None,
#   'relations': {'Replace': 'K. Irving - BOS'},
#   'attributes': None}]

# %%
reader.extract_all(pbp_dict, "./Data/Games/")
# Out:
# Total Games: 1312
# Parse 0th game
# Saved 0th game
# Parse 1th game
# Saved 1th game
# Parse 2th game
# Saved 2th game
# Parse 3th game
# Saved 3th game
# Parse 4th game
# Saved 4th game
# Parse 5th game
# Saved 5th game
# Parse 6th game
# Saved 6th game
# Parse 7th game
# Saved 7th game
# Parse 8th game
# Saved 8th game
# Parse 9th game
# Saved 9th game
# Parse 10th game
# Saved 10th game
# Parse 11th game
# Saved 11th game
# Parse 12th game
# Saved 12th game
# Parse 13th game
# Saved 13th game
# Parse 14th game
# Saved 14th game
# Parse 15th game
# Saved 15th game
# Parse 16th game
# Saved 16th game
# Parse 17th game
# Saved 17th game
# Parse 18th game
# Saved 18th game
# Parse 19th game
# Saved 19th game
# Parse 20th game
# Saved 20th game
# Parse 21th game
# Saved 21th game
# Parse 22th game
# Saved 22th game
# Parse 23th game
# Saved 23th game
# Parse 24th game
# Saved 24th game
# Parse 25th game
# Saved 25th game
# Parse 26th game
# Saved 26th game
# Parse 27th game
# Saved 27th game
# Parse 28th game
# Saved 28th game
# Parse 29th game
# Saved 29th game
# Parse 30th game
# Saved 30th game
# Parse 31th game
# Saved 31th game
# Parse 32th game
# Saved 32th game
# Parse 33th game
# Saved 33th game
# Parse 34th game
# Saved 34th game
# Parse 35th game
# Saved 35th game
# Parse 36th game
# Saved 36th game
# Parse 37th game
# Saved 37th game
# Parse 38th game
# Saved 38th game
# Parse 39th game
# Saved 39th game
# Parse 40th game
# Saved 40th game
# Parse 41th game
# Saved 41th game
# Parse 42th game
# Saved 42th game
# Parse 43th game
# Saved 43th game
# Parse 44th game
# Saved 44th game
# Parse 45th game
# Saved 45th game
# Parse 46th game
# Saved 46th game
# Parse 47th game
# Saved 47th game
# Parse 48th game
# Saved 48th game
# Parse 49th game
# Saved 49th game
# Parse 50th game
# Saved 50th game
# Parse 51th game
# Saved 51th game
# Parse 52th game
# Saved 52th game
# Parse 53th game
# Saved 53th game
# Parse 54th game
# Saved 54th game
# Parse 55th game
# Saved 55th game
# Parse 56th game
# Saved 56th game
# Parse 57th game
# Saved 57th game
# Parse 58th game
# Saved 58th game
# Parse 59th game
